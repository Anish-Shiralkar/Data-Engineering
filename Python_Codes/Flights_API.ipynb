# %%
import pandas as pd
import requests

# %% [markdown]
# # Airports data

# %% [markdown]
# ## Calling the API

# %%
#The URL for the API endpoint we're accessing, which searches for airports near a specific location
# In this case, the API endpoint expects the latitude, longitude, radius, and other parameters to be part of the URL path, not as query parameters. querystring = {"withFlightInfoOnly":"true"} # A dictionary containing query parameters for the API request
url = "https://aerodatabox.p.rapidapi.com/airports/search/location/52.31/13.24/km/50/10" 

querystring = {"lat":"52.31","lon":"13.24","radiusKm":"50","limit":"10","withFlightInfoOnly":"true"}


headers = {
	"X-RapidAPI-Key": #"Your Key",
	"X-RapidAPI-Host": "aerodatabox.p.rapidapi.com" # A dictionary containing headers for the API request, including the API key and host
}

response = requests.request("GET", url, headers=headers, params=querystring) # Making a GET request to the API endpoint with the specified headers and query parameters

print(response.text) # Printing the text content of the response from the API
# Out:
# {"searchBy":{"lat":52.31,"lon":13.24},"count":1,"items":[{"icao":"EDDB","iata":"BER","name":"Berlin Brandenburg","shortName":"Brandenburg","municipalityName":"Berlin","location":{"lat":52.35139,"lon":13.493889},"countryCode":"DE","timeZone":"Europe/Berlin"}]}

# %%
response.json() # Converting JSON response to a python dictionary
# Out:
# {'searchBy': {'lat': 52.31, 'lon': 13.24},
#  'count': 1,
#  'items': [{'icao': 'EDDB',
#    'iata': 'BER',
#    'name': 'Berlin Brandenburg',
#    'shortName': 'Brandenburg',
#    'municipalityName': 'Berlin',
#    'location': {'lat': 52.35139, 'lon': 13.493889},
#    'countryCode': 'DE',
#    'timeZone': 'Europe/Berlin'}]}

# %%
pd.json_normalize(response.json()['items']) # Normalizing the JSON data in the 'items' key into a flat table (dataframe)
# Out:
#    icao iata                name    shortName municipalityName countryCode  \
# 0  EDDB  BER  Berlin Brandenburg  Brandenburg           Berlin          DE
#
#         timeZone  location.lat  location.lon
# 0  Europe/Berlin      52.35139     13.493889

# %% [markdown]
# ## Creating a function to work with multiple cities

# %%
# Defining a function to retrieve ICAO airport codes given lists of latitudes and longitudes
def icao_airport_codes(latitudes, longitudes):
    
    # Assert len(latitudes) == len(longitudes)
    
    
    list_for_df = []  # Initializing an empty list to store dataframes
    
    for index, value in enumerate(latitudes): # Looping through the latitudes and corresponding longitudes
        url = f"https://aerodatabox.p.rapidapi.com/airports/search/location/{value}/{longitudes[index]}/km/50/5"
        querystring = {"withFlightInfoOnly":"true"}

        headers = {
          "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com",
          "X-RapidAPI-Key": #"Your Key"
        }

        response = requests.request("GET", url, headers=headers, params=querystring)
        
        # Normalizing the JSON response and append the resulting dataframe to the list
        list_for_df.append(pd.json_normalize(response.json()['items']))
        

    return pd.concat(list_for_df, ignore_index=True)  # Concatenating all dataframes in the list into a single dataframe and return it

# %%
list(enumerate(latitudes)) # Create an enumerated list of tuples from the latitudes list (index, value)
# Out:
# [(0, 52.52), (1, 53.5511), (2, 48.1351)]

# %%
# Entering the coordinates for Berlin, Paris, London (Desired Cities)
latitudes = [52.5200, 53.5511, 48.1351]
longitudes = [13.4050, 9.9937, 11.5820]

icao_airport_codes(latitudes, longitudes) # Calling the function
# Out:
#    icao iata                name    shortName municipalityName countryCode  \
# 0  EDDB  BER  Berlin Brandenburg  Brandenburg           Berlin          DE
# 1  EDDH  HAM            Hamburg       Hamburg          Hamburg          DE
# 2  EDDM  MUC             Munich        Munich           Munich          DE
#
#         timeZone  location.lat  location.lon
# 0  Europe/Berlin      52.35139     13.493889
# 1  Europe/Berlin      53.63040      9.988229
# 2  Europe/Berlin      48.35380     11.786100

# %% [markdown]
# # Flights data

# %% [markdown]
# ## Calling the API

# %%
import pandas as pd
from datetime import datetime, timedelta
import requests
from pytz import timezone

# %%
# Defining the parameters

icao = "EDDB" # For Berlin airport
date = datetime.now().date()
time_1 = "00:00"
time_2 = "11:59"

url =  f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/{date}T{time_1}/{date}T{time_2}"

querystring = {"withLeg":"true",
               "direction":"Arrival",
               "withCancelled":"false",
               "withCodeshared":"true",
               "withCargo":"false",
               "withPrivate":"false"}

headers = {
    'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
    'x-rapidapi-key': #"Your Key"
    }

response = requests.request("GET",
                            url,
                            headers = headers,
                            params = querystring)

flights_json = response.json()

flights_json
# Out:
# {'arrivals': [{'departure': {'airport': {'icao': 'EDDK',
#      'iata': 'CGN',
#      'name': 'Cologne',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-07-08 02:46Z',
#      'local': '2024-07-08 04:46+02:00'},
#     'revisedTime': {'utc': '2024-07-08 02:46Z',
#      'local': '2024-07-08 04:46+02:00'},
#     'runwayTime': {'utc': '2024-07-08 02:46Z',
#      'local': '2024-07-08 04:46+02:00'},
#     'runway': '06',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 03:25Z',
#      'local': '2024-07-08 05:25+02:00'},
#     'revisedTime': {'utc': '2024-07-08 03:25Z',
#      'local': '2024-07-08 05:25+02:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'DJ 6228',
#    'callSign': 'SRR6228',
#    'status': 'Approaching',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OY-SRM', 'modeS': '45CE4D', 'model': 'Boeing 767'},
#    'airline': {'name': 'Star Air A/S', 'iata': 'DJ', 'icao': 'SRR'}},
#   {'departure': {'airport': {'icao': 'UGTB',
#      'iata': 'TBS',
#      'name': 'Tbilisi',
#      'timeZone': 'Asia/Tbilisi'},
#     'scheduledTime': {'utc': '2024-07-07 23:20Z',
#      'local': '2024-07-08 03:20+04:00'},
#     'revisedTime': {'utc': '2024-07-08 00:28Z',
#      'local': '2024-07-08 04:28+04:00'},
#     'checkInDesk': '02',
#     'gate': '102',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 03:40Z',
#      'local': '2024-07-08 05:40+02:00'},
#     'revisedTime': {'utc': '2024-07-08 04:10Z',
#      'local': '2024-07-08 06:10+02:00'},
#     'terminal': '1',
#     'gate': 'X02',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8993',
#    'callSign': 'EWG8993',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-MLP', 'modeS': '4D239F', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'ZBAA',
#      'iata': 'PEK',
#      'name': 'Beijing',
#      'timeZone': 'Asia/Shanghai'},
#     'scheduledTime': {'utc': '2024-07-07 19:10Z',
#      'local': '2024-07-08 03:10+08:00'},
#     'revisedTime': {'utc': '2024-07-07 19:15Z',
#      'local': '2024-07-08 03:15+08:00'},
#     'terminal': '2',
#     'checkInDesk': 'C11-C15',
#     'gate': '08',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 04:45Z',
#      'local': '2024-07-08 06:45+02:00'},
#     'revisedTime': {'utc': '2024-07-08 04:34Z',
#      'local': '2024-07-08 06:34+02:00'},
#     'runwayTime': {'utc': '2024-07-08 04:34Z',
#      'local': '2024-07-08 06:34+02:00'},
#     'terminal': '1',
#     'gate': 'X17',
#     'baggageBelt': 'A2',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'HU 489',
#    'callSign': 'CHH489',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'B-1021', 'modeS': '7812A3', 'model': 'Airbus A330'},
#    'airline': {'name': 'Hainan', 'iata': 'HU', 'icao': 'CHH'}},
#   {'departure': {'airport': {'icao': 'EVRA',
#      'iata': 'RIX',
#      'name': 'Riga',
#      'timeZone': 'Europe/Riga'},
#     'scheduledTime': {'utc': '2024-07-08 04:00Z',
#      'local': '2024-07-08 07:00+03:00'},
#     'revisedTime': {'utc': '2024-07-08 04:00Z',
#      'local': '2024-07-08 07:00+03:00'},
#     'terminal': 'B',
#     'gate': 'B17',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 05:40Z',
#      'local': '2024-07-08 07:40+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:35Z',
#      'local': '2024-07-08 07:35+02:00'},
#     'runwayTime': {'utc': '2024-07-08 05:35Z',
#      'local': '2024-07-08 07:35+02:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A4',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'BT 211',
#    'callSign': 'BTI74A',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'YL-ABP',
#     'modeS': '502D7A',
#     'model': 'Airbus A220-300'},
#    'airline': {'name': 'airBaltic', 'iata': 'BT', 'icao': 'BTI'}},
#   {'departure': {'airport': {'icao': 'EVRA',
#      'iata': 'RIX',
#      'name': 'Riga',
#      'timeZone': 'Europe/Riga'},
#     'scheduledTime': {'utc': '2024-07-08 04:00Z',
#      'local': '2024-07-08 07:00+03:00'},
#     'revisedTime': {'utc': '2024-07-08 04:00Z',
#      'local': '2024-07-08 07:00+03:00'},
#     'terminal': 'B',
#     'gate': 'B17',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 05:40Z',
#      'local': '2024-07-08 07:40+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:35Z',
#      'local': '2024-07-08 07:35+02:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 7313',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'YL-ABP',
#     'modeS': '502D7A',
#     'model': 'Airbus A220-300'},
#    'airline': {'name': 'Delta Air Lines', 'iata': 'DL', 'icao': 'DAL'}},
#   {'departure': {'airport': {'icao': 'KJFK',
#      'iata': 'JFK',
#      'name': 'New York',
#      'timeZone': 'America/New_York'},
#     'scheduledTime': {'utc': '2024-07-07 21:45Z',
#      'local': '2024-07-07 17:45-04:00'},
#     'revisedTime': {'utc': '2024-07-07 22:10Z',
#      'local': '2024-07-07 18:10-04:00'},
#     'runwayTime': {'utc': '2024-07-07 22:10Z',
#      'local': '2024-07-07 18:10-04:00'},
#     'terminal': '4',
#     'runway': '13R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 05:50Z',
#      'local': '2024-07-08 07:50+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:06Z',
#      'local': '2024-07-08 07:06+02:00'},
#     'runwayTime': {'utc': '2024-07-08 05:06Z',
#      'local': '2024-07-08 07:06+02:00'},
#     'terminal': '1',
#     'gate': 'Y02',
#     'baggageBelt': 'B3',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 92',
#    'callSign': 'DAL92',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'N177DZ', 'modeS': 'A13391', 'model': 'Boeing 767-300'},
#    'airline': {'name': 'Delta Air Lines', 'iata': 'DL', 'icao': 'DAL'}},
#   {'departure': {'airport': {'icao': 'EDDR',
#      'iata': 'SCN',
#      'name': 'Saarbrücken',
#      'timeZone': 'Europe/Berlin'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 05:42Z',
#      'local': '2024-07-08 07:42+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:42Z',
#      'local': '2024-07-08 07:42+02:00'},
#     'runwayTime': {'utc': '2024-07-08 05:42Z',
#      'local': '2024-07-08 07:42+02:00'},
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'DMS 2PV',
#    'callSign': 'DMS2PV',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OY-RUO', 'modeS': '45CAAF', 'model': 'ATR 42'},
#    'airline': {'name': 'DMS'}},
#   {'departure': {'airport': {'icao': 'EDDK',
#      'iata': 'CGN',
#      'name': 'Cologne',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-07-08 04:30Z',
#      'local': '2024-07-08 06:30+02:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 05:40Z',
#      'local': '2024-07-08 07:40+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:24Z',
#      'local': '2024-07-08 07:24+02:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 12',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ABZL', 'modeS': '3C4B4C', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-07-08 04:15Z',
#      'local': '2024-07-08 06:15+02:00'},
#     'revisedTime': {'utc': '2024-07-08 04:15Z',
#      'local': '2024-07-08 06:15+02:00'},
#     'terminal': '3',
#     'gate': '140',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 05:25Z',
#      'local': '2024-07-08 07:25+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:18Z',
#      'local': '2024-07-08 07:18+02:00'},
#     'terminal': '1',
#     'gate': 'A36',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 2002',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ABGQ', 'modeS': '3C48F1', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'LTAJ',
#      'iata': 'GZT',
#      'name': 'Gaziantep',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-07-08 00:55Z',
#      'local': '2024-07-08 03:55+03:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 04:45Z',
#      'local': '2024-07-08 06:45+02:00'},
#     'revisedTime': {'utc': '2024-07-08 04:41Z',
#      'local': '2024-07-08 06:41+02:00'},
#     'terminal': '1',
#     'gate': 'N02',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'XQ 1766',
#    'callSign': 'SXS1ZP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-SPA', 'modeS': '4BCE01', 'model': 'Boeing 737'},
#    'airline': {'name': 'Sun Express', 'iata': 'XQ', 'icao': 'SXS'}},
#   {'departure': {'airport': {'icao': 'LTBJ',
#      'iata': 'ADB',
#      'name': 'İzmir',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-07-08 01:25Z',
#      'local': '2024-07-08 04:25+03:00'},
#     'revisedTime': {'utc': '2024-07-08 01:34Z',
#      'local': '2024-07-08 04:34+03:00'},
#     'runwayTime': {'utc': '2024-07-08 01:37Z',
#      'local': '2024-07-08 04:37+03:00'},
#     'checkInDesk': '08',
#     'gate': '111',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 04:30Z',
#      'local': '2024-07-08 06:30+02:00'},
#     'revisedTime': {'utc': '2024-07-08 04:05Z',
#      'local': '2024-07-08 06:05+02:00'},
#     'terminal': '1',
#     'gate': 'X01',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'XQ 966',
#    'callSign': 'SXS5D',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-SRB', 'modeS': '4BCE42', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Sun Express', 'iata': 'XQ', 'icao': 'SXS'}},
#   {'departure': {'airport': {'icao': 'EVRA',
#      'iata': 'RIX',
#      'name': 'Riga',
#      'timeZone': 'Europe/Riga'},
#     'scheduledTime': {'utc': '2024-07-08 04:00Z',
#      'local': '2024-07-08 07:00+03:00'},
#     'revisedTime': {'utc': '2024-07-08 04:00Z',
#      'local': '2024-07-08 07:00+03:00'},
#     'terminal': 'B',
#     'gate': 'B17',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 05:40Z',
#      'local': '2024-07-08 07:40+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:35Z',
#      'local': '2024-07-08 07:35+02:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'A3 3219',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'YL-ABP',
#     'modeS': '502D7A',
#     'model': 'Airbus A220-300'},
#    'airline': {'name': 'Aegean', 'iata': 'A3', 'icao': 'AEE'}},
#   {'departure': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-07-08 04:20Z',
#      'local': '2024-07-08 06:20+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:03Z',
#      'local': '2024-07-08 07:03+02:00'},
#     'runwayTime': {'utc': '2024-07-08 05:09Z',
#      'local': '2024-07-08 07:09+02:00'},
#     'terminal': 'B',
#     'checkInDesk': '151,170',
#     'gate': 'A54',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 05:30Z',
#      'local': '2024-07-08 07:30+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:55Z',
#      'local': '2024-07-08 07:55+02:00'},
#     'terminal': '1',
#     'gate': 'B20',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 9048',
#    'callSign': 'GWI52FP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AGWG', 'modeS': '3C5EE7', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EYVI',
#      'iata': 'VNO',
#      'name': 'Vilnius',
#      'timeZone': 'Europe/Vilnius'},
#     'scheduledTime': {'utc': '2024-07-08 04:10Z',
#      'local': '2024-07-08 07:10+03:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 05:50Z',
#      'local': '2024-07-08 07:50+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:40Z',
#      'local': '2024-07-08 07:40+02:00'},
#     'runwayTime': {'utc': '2024-07-08 05:40Z',
#      'local': '2024-07-08 07:40+02:00'},
#     'terminal': '2',
#     'gate': 'Z32',
#     'baggageBelt': 'C3',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 1571',
#    'callSign': 'RYR16HT',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SP-RSL', 'modeS': '48C22B', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EVRA',
#      'iata': 'RIX',
#      'name': 'Riga',
#      'timeZone': 'Europe/Riga'},
#     'scheduledTime': {'utc': '2024-07-08 04:00Z',
#      'local': '2024-07-08 07:00+03:00'},
#     'revisedTime': {'utc': '2024-07-08 04:00Z',
#      'local': '2024-07-08 07:00+03:00'},
#     'terminal': 'B',
#     'gate': 'B17',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 05:40Z',
#      'local': '2024-07-08 07:40+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:35Z',
#      'local': '2024-07-08 07:35+02:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'JU 7659',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'YL-ABP',
#     'modeS': '502D7A',
#     'model': 'Airbus A220-300'},
#    'airline': {'name': 'JU'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-07-08 04:45Z',
#      'local': '2024-07-08 06:45+02:00'},
#     'revisedTime': {'utc': '2024-07-08 04:45Z',
#      'local': '2024-07-08 06:45+02:00'},
#     'runwayTime': {'utc': '2024-07-08 05:10Z',
#      'local': '2024-07-08 07:10+02:00'},
#     'terminal': '1',
#     'checkInDesk': '259-335',
#     'gate': 'A23',
#     'runway': '25C',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 05:55Z',
#      'local': '2024-07-08 07:55+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:52Z',
#      'local': '2024-07-08 07:52+02:00'},
#     'terminal': '1',
#     'gate': 'A02',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 170',
#    'callSign': 'DLH1PT',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIUC',
#     'modeS': '3C66A3',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-07-08 04:15Z',
#      'local': '2024-07-08 06:15+02:00'},
#     'revisedTime': {'utc': '2024-07-08 04:15Z',
#      'local': '2024-07-08 06:15+02:00'},
#     'terminal': '1',
#     'checkInDesk': '259-335',
#     'gate': 'A52',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 05:25Z',
#      'local': '2024-07-08 07:25+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:14Z',
#      'local': '2024-07-08 07:14+02:00'},
#     'terminal': '1',
#     'gate': 'B03',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 172',
#    'callSign': 'DLH172',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIDA', 'modeS': '3C6481', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart',
#      'timeZone': 'Europe/Berlin'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 05:25Z',
#      'local': '2024-07-08 07:25+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:18Z',
#      'local': '2024-07-08 07:18+02:00'},
#     'terminal': '1',
#     'gate': 'A36',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 5385',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ABGQ', 'modeS': '3C48F1', 'model': 'Airbus A319'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'OTHH',
#      'iata': 'DOH',
#      'name': 'Doha',
#      'timeZone': 'Asia/Qatar'},
#     'scheduledTime': {'utc': '2024-07-07 23:20Z',
#      'local': '2024-07-08 02:20+03:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 05:20Z',
#      'local': '2024-07-08 07:20+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:10Z',
#      'local': '2024-07-08 07:10+02:00'},
#     'runwayTime': {'utc': '2024-07-08 05:10Z',
#      'local': '2024-07-08 07:10+02:00'},
#     'terminal': '1',
#     'gate': 'X07',
#     'baggageBelt': 'A3',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'QR 79',
#    'callSign': 'QTR32A',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'A7-BHN', 'modeS': '06A2F1', 'model': 'Boeing 787-9'},
#    'airline': {'name': 'Qatar Airways', 'iata': 'QR', 'icao': 'QTR'}},
#   {'departure': {'airport': {'icao': 'KEWR',
#      'iata': 'EWR',
#      'name': 'Newark',
#      'timeZone': 'America/New_York'},
#     'scheduledTime': {'utc': '2024-07-07 21:05Z',
#      'local': '2024-07-07 17:05-04:00'},
#     'revisedTime': {'utc': '2024-07-07 21:47Z',
#      'local': '2024-07-07 17:47-04:00'},
#     'runwayTime': {'utc': '2024-07-07 21:47Z',
#      'local': '2024-07-07 17:47-04:00'},
#     'terminal': 'C',
#     'runway': '04L',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 05:15Z',
#      'local': '2024-07-08 07:15+02:00'},
#     'revisedTime': {'utc': '2024-07-08 04:49Z',
#      'local': '2024-07-08 06:49+02:00'},
#     'terminal': '1',
#     'gate': 'Y17',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'UA 962',
#    'callSign': 'UAL962',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'N69063', 'modeS': 'A92DFC', 'model': 'Boeing 767-400'},
#    'airline': {'name': 'United', 'iata': 'UA', 'icao': 'UAL'}},
#   {'departure': {'airport': {'icao': 'LFPG',
#      'iata': 'CDG',
#      'name': 'Paris',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-07-08 05:00Z',
#      'local': '2024-07-08 07:00+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:18Z',
#      'local': '2024-07-08 07:18+02:00'},
#     'runwayTime': {'utc': '2024-07-08 05:18Z',
#      'local': '2024-07-08 07:18+02:00'},
#     'terminal': '2F',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 06:40Z',
#      'local': '2024-07-08 08:40+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:30Z',
#      'local': '2024-07-08 08:30+02:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'AF 1434',
#    'callSign': 'AFR95ZE',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'F-HDRF', 'modeS': '398E25', 'model': 'Airbus A320'},
#    'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#   {'departure': {'airport': {'icao': 'EFHK',
#      'iata': 'HEL',
#      'name': 'Helsinki',
#      'timeZone': 'Europe/Helsinki'},
#     'scheduledTime': {'utc': '2024-07-08 04:05Z',
#      'local': '2024-07-08 07:05+03:00'},
#     'revisedTime': {'utc': '2024-07-08 04:04Z',
#      'local': '2024-07-08 07:04+03:00'},
#     'runwayTime': {'utc': '2024-07-08 04:15Z',
#      'local': '2024-07-08 07:15+03:00'},
#     'terminal': '2',
#     'checkInDesk': '211',
#     'gate': '30',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 06:05Z',
#      'local': '2024-07-08 08:05+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:59Z',
#      'local': '2024-07-08 07:59+02:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'AY 1431',
#    'callSign': 'FIN3AW',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OH-LZH',
#     'modeS': '461F9D',
#     'model': 'Airbus A321 (Sharklets)'},
#    'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#   {'departure': {'airport': {'icao': 'EDDR',
#      'iata': 'SCN',
#      'name': 'Saarbrücken',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-07-08 04:30Z',
#      'local': '2024-07-08 06:30+02:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 06:05Z',
#      'local': '2024-07-08 08:05+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:43Z',
#      'local': '2024-07-08 07:43+02:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'DX 121',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OY-RUO', 'modeS': '45CAAF', 'model': 'ATR 42'},
#    'airline': {'name': 'Danish Air', 'iata': 'DX', 'icao': 'DTR'}},
#   {'departure': {'airport': {'icao': 'ENGM',
#      'iata': 'OSL',
#      'name': 'Oslo',
#      'timeZone': 'Europe/Oslo'},
#     'scheduledTime': {'utc': '2024-07-08 05:00Z',
#      'local': '2024-07-08 07:00+02:00'},
#     'revisedTime': {'utc': '2024-07-08 04:54Z',
#      'local': '2024-07-08 06:54+02:00'},
#     'runwayTime': {'utc': '2024-07-08 05:07Z',
#      'local': '2024-07-08 07:07+02:00'},
#     'checkInDesk': '123',
#     'gate': 'D4',
#     'runway': '19L',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 06:35Z',
#      'local': '2024-07-08 08:35+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:25Z',
#      'local': '2024-07-08 08:25+02:00'},
#     'terminal': '2',
#     'gate': 'Z34',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'DY 1100',
#    'callSign': 'NOZ1100',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'LN-DYR', 'modeS': '47875C', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Norwegian Air Shuttle', 'iata': 'DY', 'icao': 'NOZ'}},
#   {'departure': {'airport': {'icao': 'LIML',
#      'iata': 'LIN',
#      'name': 'Milan',
#      'timeZone': 'Europe/Rome'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 06:35Z',
#      'local': '2024-07-08 08:35+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:27Z',
#      'local': '2024-07-08 08:27+02:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5068',
#    'callSign': 'EJU5068',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICL',
#     'modeS': '4404A4',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen',
#      'timeZone': 'Europe/Copenhagen'},
#     'scheduledTime': {'utc': '2024-07-08 05:50Z',
#      'local': '2024-07-08 07:50+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:50Z',
#      'local': '2024-07-08 07:50+02:00'},
#     'runwayTime': {'utc': '2024-07-08 05:53Z',
#      'local': '2024-07-08 07:53+02:00'},
#     'terminal': 'erminal2',
#     'gate': 'F7',
#     'runway': '22R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 06:55Z',
#      'local': '2024-07-08 08:55+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:34Z',
#      'local': '2024-07-08 08:34+02:00'},
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5262',
#    'callSign': 'EJU48QZ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDS', 'modeS': '440DA5', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'ESSA',
#      'iata': 'ARN',
#      'name': 'Stockholm',
#      'timeZone': 'Europe/Stockholm'},
#     'scheduledTime': {'utc': '2024-07-08 04:30Z',
#      'local': '2024-07-08 06:30+02:00'},
#     'revisedTime': {'utc': '2024-07-08 04:36Z',
#      'local': '2024-07-08 06:36+02:00'},
#     'runwayTime': {'utc': '2024-07-08 04:48Z',
#      'local': '2024-07-08 06:48+02:00'},
#     'terminal': '5',
#     'checkInDesk': '25-27',
#     'gate': 'C43',
#     'runway': '19R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 06:05Z',
#      'local': '2024-07-08 08:05+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:05Z',
#      'local': '2024-07-08 08:05+02:00'},
#     'runwayTime': {'utc': '2024-07-08 06:05Z',
#      'local': '2024-07-08 08:05+02:00'},
#     'terminal': '1',
#     'gate': 'A38',
#     'baggageBelt': 'A1',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 4600',
#    'callSign': 'EWG4600',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-EUR',
#     'modeS': '4D2406',
#     'model': 'Airbus A320-200'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'LCPH',
#      'iata': 'PFO',
#      'name': 'Paphos',
#      'timeZone': 'Asia/Nicosia'},
#     'scheduledTime': {'utc': '2024-07-08 03:00Z',
#      'local': '2024-07-08 06:00+03:00'},
#     'revisedTime': {'utc': '2024-07-08 03:24Z',
#      'local': '2024-07-08 06:24+03:00'},
#     'runwayTime': {'utc': '2024-07-08 03:24Z',
#      'local': '2024-07-08 06:24+03:00'},
#     'runway': '29',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 06:45Z',
#      'local': '2024-07-08 08:45+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:43Z',
#      'local': '2024-07-08 08:43+02:00'},
#     'terminal': '2',
#     'gate': 'Z38',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 354',
#    'callSign': 'RYR354',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-IHB',
#     'modeS': '4CADE7',
#     'model': 'Boeing 737 MAX 8'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LYBE',
#      'iata': 'BEG',
#      'name': 'Belgrade',
#      'timeZone': 'Europe/Belgrade'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 06:40Z',
#      'local': '2024-07-08 08:40+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:45Z',
#      'local': '2024-07-08 08:45+02:00'},
#     'terminal': '1',
#     'gate': 'X17',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'JA 354',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'YU-APL', 'modeS': '4C01EB', 'model': 'Airbus A319'},
#    'airline': {'name': 'JetSMART', 'iata': 'JA', 'icao': 'JAT'}},
#   {'departure': {'airport': {'icao': 'LYBE',
#      'iata': 'BEG',
#      'name': 'Belgrade',
#      'timeZone': 'Europe/Belgrade'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 06:51Z',
#      'local': '2024-07-08 08:51+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:51Z',
#      'local': '2024-07-08 08:51+02:00'},
#     'runwayTime': {'utc': '2024-07-08 06:45Z',
#      'local': '2024-07-08 08:45+02:00'},
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'JU 37H',
#    'callSign': 'ASL37H',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'YU-APL', 'modeS': '4C01EB', 'model': 'Airbus A319'},
#    'airline': {'name': 'Air Serbia', 'iata': 'JU', 'icao': 'ASL'}},
#   {'departure': {'airport': {'icao': 'ELLX',
#      'iata': 'LUX',
#      'name': 'Luxembourg',
#      'timeZone': 'Europe/Luxembourg'},
#     'scheduledTime': {'utc': '2024-07-08 04:35Z',
#      'local': '2024-07-08 06:35+02:00'},
#     'revisedTime': {'utc': '2024-07-08 04:35Z',
#      'local': '2024-07-08 06:35+02:00'},
#     'runwayTime': {'utc': '2024-07-08 04:59Z',
#      'local': '2024-07-08 06:59+02:00'},
#     'terminal': 'A',
#     'gate': 'B04',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 06:05Z',
#      'local': '2024-07-08 08:05+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:10Z',
#      'local': '2024-07-08 08:10+02:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LG 9471',
#    'callSign': 'LGL91B',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'LX-LGE',
#     'modeS': '4D00C6',
#     'model': 'De Havilland Canada DHC-8-400 Dash 8Q'},
#    'airline': {'name': 'Luxair', 'iata': 'LG', 'icao': 'LGL'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-07-08 05:45Z',
#      'local': '2024-07-08 07:45+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:45Z',
#      'local': '2024-07-08 07:45+02:00'},
#     'terminal': '1',
#     'checkInDesk': '259-335',
#     'gate': 'A13',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 06:55Z',
#      'local': '2024-07-08 08:55+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:57Z',
#      'local': '2024-07-08 08:57+02:00'},
#     'runwayTime': {'utc': '2024-07-08 06:56Z',
#      'local': '2024-07-08 08:56+02:00'},
#     'terminal': '1',
#     'gate': 'B03',
#     'baggageBelt': 'B4',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 174',
#    'callSign': 'DLH4PH',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIBG', 'modeS': '3C6447', 'model': 'Airbus A319'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'ESSA',
#      'iata': 'ARN',
#      'name': 'Stockholm',
#      'timeZone': 'Europe/Stockholm'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 06:05Z',
#      'local': '2024-07-08 08:05+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:05Z',
#      'local': '2024-07-08 08:05+02:00'},
#     'terminal': '1',
#     'gate': 'A38',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 5344',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-EUR', 'model': 'Airbus A320-200'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-07-08 05:20Z',
#      'local': '2024-07-08 07:20+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:30Z',
#      'local': '2024-07-08 07:30+02:00'},
#     'runwayTime': {'utc': '2024-07-08 05:43Z',
#      'local': '2024-07-08 07:43+02:00'},
#     'checkInDesk': '1',
#     'gate': 'B31',
#     'runway': '28',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 06:45Z',
#      'local': '2024-07-08 08:45+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:49Z',
#      'local': '2024-07-08 08:49+02:00'},
#     'runwayTime': {'utc': '2024-07-08 06:50Z',
#      'local': '2024-07-08 08:50+02:00'},
#     'terminal': '1',
#     'gate': 'B07',
#     'baggageBelt': 'B1',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 974',
#    'callSign': 'SWR97Y',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'YL-ABM',
#     'modeS': '502D5E',
#     'model': 'Airbus A220-300'},
#    'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#   {'departure': {'airport': {'icao': 'LOWW',
#      'iata': 'VIE',
#      'name': 'Vienna',
#      'timeZone': 'Europe/Vienna'},
#     'scheduledTime': {'utc': '2024-07-08 05:00Z',
#      'local': '2024-07-08 07:00+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:08Z',
#      'local': '2024-07-08 07:08+02:00'},
#     'runwayTime': {'utc': '2024-07-08 05:09Z',
#      'local': '2024-07-08 07:09+02:00'},
#     'terminal': '3',
#     'checkInDesk': '351-372',
#     'gate': 'F25',
#     'runway': '34',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 06:10Z',
#      'local': '2024-07-08 08:10+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:56Z',
#      'local': '2024-07-08 07:56+02:00'},
#     'terminal': '1',
#     'gate': 'A06',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 223',
#    'callSign': 'AUA223',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LXE', 'modeS': '4402A3', 'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#   {'departure': {'airport': {'icao': 'LTAI',
#      'iata': 'AYT',
#      'name': 'Antalya',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-07-08 03:05Z',
#      'local': '2024-07-08 06:05+03:00'},
#     'revisedTime': {'utc': '2024-07-08 04:00Z',
#      'local': '2024-07-08 07:00+03:00'},
#     'terminal': '1',
#     'checkInDesk': '107-109',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 06:35Z',
#      'local': '2024-07-08 08:35+02:00'},
#     'revisedTime': {'utc': '2024-07-08 07:43Z',
#      'local': '2024-07-08 09:43+02:00'},
#     'terminal': '1',
#     'gate': 'N02',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'PC 5067',
#    'callSign': 'PGT4WR',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-NCM',
#     'modeS': '4BB86D',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Pegasus', 'iata': 'PC', 'icao': 'PGT'}},
#   {'departure': {'airport': {'icao': 'HEMA',
#      'iata': 'RMF',
#      'name': 'Marsa Alam',
#      'timeZone': 'Africa/Cairo'},
#     'scheduledTime': {'utc': '2024-07-08 01:10Z',
#      'local': '2024-07-08 04:10+03:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 06:10Z',
#      'local': '2024-07-08 08:10+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:26Z',
#      'local': '2024-07-08 07:26+02:00'},
#     'terminal': '1',
#     'gate': 'N02',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'SM 2962',
#    'callSign': 'MSC2962',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SU-BUK',
#     'modeS': '01022C',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Air Cairo', 'iata': 'SM', 'icao': 'MSC'}},
#   {'departure': {'airport': {'icao': 'LIML',
#      'iata': 'LIN',
#      'name': 'Milan',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-07-08 04:55Z',
#      'local': '2024-07-08 06:55+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:12Z',
#      'local': '2024-07-08 07:12+02:00'},
#     'runwayTime': {'utc': '2024-07-08 05:12Z',
#      'local': '2024-07-08 07:12+02:00'},
#     'runway': '36',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 06:35Z',
#      'local': '2024-07-08 08:35+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:27Z',
#      'local': '2024-07-08 08:27+02:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5068',
#    'callSign': 'EZY5068',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICL',
#     'modeS': '4404A4',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen',
#      'timeZone': 'Europe/Copenhagen'},
#     'scheduledTime': {'utc': '2024-07-08 05:50Z',
#      'local': '2024-07-08 07:50+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:50Z',
#      'local': '2024-07-08 07:50+02:00'},
#     'runwayTime': {'utc': '2024-07-08 05:53Z',
#      'local': '2024-07-08 07:53+02:00'},
#     'terminal': 'erminal2',
#     'gate': 'F7',
#     'runway': '22R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 06:55Z',
#      'local': '2024-07-08 08:55+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:34Z',
#      'local': '2024-07-08 08:34+02:00'},
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5262',
#    'callSign': 'EJU48QZ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDS', 'modeS': '440DA5', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LFST',
#      'iata': 'SXB',
#      'name': 'Strasbourg',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-07-08 04:30Z',
#      'local': '2024-07-08 06:30+02:00'},
#     'revisedTime': {'utc': '2024-07-08 04:36Z',
#      'local': '2024-07-08 06:36+02:00'},
#     'runwayTime': {'utc': '2024-07-08 04:36Z',
#      'local': '2024-07-08 06:36+02:00'},
#     'runway': '23',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 06:00Z',
#      'local': '2024-07-08 08:00+02:00'},
#     'revisedTime': {'utc': '2024-07-08 05:33Z',
#      'local': '2024-07-08 07:33+02:00'},
#     'runwayTime': {'utc': '2024-07-08 05:33Z',
#      'local': '2024-07-08 07:33+02:00'},
#     'terminal': '1',
#     'gate': 'A35',
#     'baggageBelt': 'A2',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'V7 2596',
#    'callSign': 'VOE2UD',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EC-NPC', 'modeS': '346648', 'model': 'Airbus A320'},
#    'airline': {'name': 'Volotea', 'iata': 'V7', 'icao': 'VOE'}},
#   {'departure': {'airport': {'icao': 'DTTA',
#      'iata': 'TUN',
#      'name': 'Tunis',
#      'timeZone': 'Africa/Tunis'},
#     'scheduledTime': {'utc': '2024-07-08 05:00Z',
#      'local': '2024-07-08 06:00+01:00'},
#     'terminal': 'M',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 07:45Z',
#      'local': '2024-07-08 09:45+02:00'},
#     'revisedTime': {'utc': '2024-07-08 07:35Z',
#      'local': '2024-07-08 09:35+02:00'},
#     'terminal': '1',
#     'gate': 'N02',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'BJ 232',
#    'callSign': 'LBT232',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TS-ING',
#     'modeS': '02A1A6',
#     'model': 'Airbus A320-200 (sharklets)'},
#    'airline': {'name': 'Nouvelair Tunisie', 'iata': 'BJ', 'icao': 'LBT'}},
#   {'departure': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-07-08 06:05Z',
#      'local': '2024-07-08 08:05+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:00Z',
#      'local': '2024-07-08 08:00+02:00'},
#     'checkInDesk': '3',
#     'gate': 'A84',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 07:40Z',
#      'local': '2024-07-08 09:40+02:00'},
#     'revisedTime': {'utc': '2024-07-08 07:34Z',
#      'local': '2024-07-08 09:34+02:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A3',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5188',
#    'callSign': 'EJU73MR',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDD', 'modeS': '440CCC', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-07-08 06:35Z',
#      'local': '2024-07-08 08:35+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:35Z',
#      'local': '2024-07-08 08:35+02:00'},
#     'terminal': '3',
#     'gate': '140',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 07:45Z',
#      'local': '2024-07-08 09:45+02:00'},
#     'revisedTime': {'utc': '2024-07-08 08:55Z',
#      'local': '2024-07-08 10:55+02:00'},
#     'terminal': '1',
#     'gate': 'A38',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8001',
#    'callSign': 'EWG8001',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-MLZ', 'modeS': '4D2494', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-07-08 06:15Z',
#      'local': '2024-07-08 08:15+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:15Z',
#      'local': '2024-07-08 08:15+02:00'},
#     'runwayTime': {'utc': '2024-07-08 06:24Z',
#      'local': '2024-07-08 08:24+02:00'},
#     'terminal': 'B',
#     'checkInDesk': '151,170',
#     'gate': 'A25',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 07:25Z',
#      'local': '2024-07-08 09:25+02:00'},
#     'revisedTime': {'utc': '2024-07-08 07:14Z',
#      'local': '2024-07-08 09:14+02:00'},
#     'terminal': '1',
#     'gate': 'A37',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8041',
#    'callSign': 'GWI9XL',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AGWK', 'modeS': '3C5EEB', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EDDK',
#      'iata': 'CGN',
#      'name': 'Cologne',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-07-08 06:15Z',
#      'local': '2024-07-08 08:15+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:50Z',
#      'local': '2024-07-08 08:50+02:00'},
#     'runwayTime': {'utc': '2024-07-08 06:50Z',
#      'local': '2024-07-08 08:50+02:00'},
#     'terminal': '1',
#     'runway': '14L',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 07:25Z',
#      'local': '2024-07-08 09:25+02:00'},
#     'revisedTime': {'utc': '2024-07-08 07:37Z',
#      'local': '2024-07-08 09:37+02:00'},
#     'terminal': '1',
#     'gate': 'A35',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8059',
#    'callSign': 'EWG9RX',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-MLP', 'modeS': '4D239F', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EGSS',
#      'iata': 'STN',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-07-08 05:30Z',
#      'local': '2024-07-08 06:30+01:00'},
#     'revisedTime': {'utc': '2024-07-08 05:40Z',
#      'local': '2024-07-08 06:40+01:00'},
#     'runwayTime': {'utc': '2024-07-08 06:00Z',
#      'local': '2024-07-08 07:00+01:00'},
#     'terminal': '1',
#     'gate': '37',
#     'runway': '22',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 07:15Z',
#      'local': '2024-07-08 09:15+02:00'},
#     'revisedTime': {'utc': '2024-07-08 07:15Z',
#      'local': '2024-07-08 09:15+02:00'},
#     'terminal': '2',
#     'gate': 'Z40',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 145',
#    'callSign': 'RYR927E',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-EXF', 'modeS': '4CAA61', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EGPH',
#      'iata': 'EDI',
#      'name': 'Edinburgh',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-07-08 05:00Z',
#      'local': '2024-07-08 06:00+01:00'},
#     'revisedTime': {'utc': '2024-07-08 05:14Z',
#      'local': '2024-07-08 06:14+01:00'},
#     'runwayTime': {'utc': '2024-07-08 05:16Z',
#      'local': '2024-07-08 06:16+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 07:00Z',
#      'local': '2024-07-08 09:00+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:51Z',
#      'local': '2024-07-08 08:51+02:00'},
#     'runwayTime': {'utc': '2024-07-08 06:51Z',
#      'local': '2024-07-08 08:51+02:00'},
#     'terminal': '2',
#     'gate': 'Z44',
#     'baggageBelt': 'C1',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 2376',
#    'callSign': 'RYR2376',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-IHV',
#     'modeS': '4CAE48',
#     'model': 'Boeing 737 MAX 8'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'UGKO',
#      'iata': 'KUT',
#      'name': 'Kutaisi',
#      'timeZone': 'Asia/Tbilisi'},
#     'scheduledTime': {'utc': '2024-07-08 02:20Z',
#      'local': '2024-07-08 06:20+04:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 06:30Z',
#      'local': '2024-07-08 08:30+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:07Z',
#      'local': '2024-07-08 08:07+02:00'},
#     'terminal': '1',
#     'gate': 'N02',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'W6 7909',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HA-LGN', 'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'Wizz Air', 'iata': 'W6', 'icao': 'WZZ'}},
#   {'departure': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf',
#      'timeZone': 'Europe/Berlin'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 07:26Z',
#      'local': '2024-07-08 09:26+02:00'},
#     'revisedTime': {'utc': '2024-07-08 07:26Z',
#      'local': '2024-07-08 09:26+02:00'},
#     'runwayTime': {'utc': '2024-07-08 07:13Z',
#      'local': '2024-07-08 09:13+02:00'},
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': '4U 9XL',
#    'callSign': 'GWI9XL',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AGWK', 'modeS': '3C5EEB', 'model': 'Airbus A319'},
#    'airline': {'name': 'Germanwings', 'iata': '4U', 'icao': 'GWI'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-07-08 06:45Z',
#      'local': '2024-07-08 08:45+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:45Z',
#      'local': '2024-07-08 08:45+02:00'},
#     'runwayTime': {'utc': '2024-07-08 07:03Z',
#      'local': '2024-07-08 09:03+02:00'},
#     'terminal': '1',
#     'checkInDesk': '259-335',
#     'gate': 'A22',
#     'runway': '18',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 07:55Z',
#      'local': '2024-07-08 09:55+02:00'},
#     'revisedTime': {'utc': '2024-07-08 07:50Z',
#      'local': '2024-07-08 09:50+02:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 176',
#    'callSign': 'DLH7PK',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
# ...
#     'checkInDesk': '151-162',
#     'gate': 'C40',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 09:15Z',
#      'local': '2024-07-08 11:15+02:00'},
#     'revisedTime': {'utc': '2024-07-08 09:05Z',
#      'local': '2024-07-08 11:05+02:00'},
#     'runwayTime': {'utc': '2024-07-08 09:04Z',
#      'local': '2024-07-08 11:04+02:00'},
#     'terminal': '1',
#     'gate': 'A36',
#     'baggageBelt': 'A3',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8751',
#    'callSign': 'EWG2NY',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIDO', 'modeS': '3C648F', 'model': 'Airbus A321'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-07-08 07:50Z',
#      'local': '2024-07-08 09:50+02:00'},
#     'revisedTime': {'utc': '2024-07-08 07:50Z',
#      'local': '2024-07-08 09:50+02:00'},
#     'runwayTime': {'utc': '2024-07-08 08:11Z',
#      'local': '2024-07-08 10:11+02:00'},
#     'checkInDesk': '2(5)',
#     'gate': 'A75',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 09:30Z',
#      'local': '2024-07-08 11:30+02:00'},
#     'revisedTime': {'utc': '2024-07-08 09:12Z',
#      'local': '2024-07-08 11:12+02:00'},
#     'runwayTime': {'utc': '2024-07-08 09:11Z',
#      'local': '2024-07-08 11:11+02:00'},
#     'terminal': '1',
#     'gate': 'A22',
#     'baggageBelt': 'B4',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8761',
#    'callSign': 'EWG2BA',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AGWF', 'modeS': '3C5EE6', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'BIKF',
#      'iata': 'KEF',
#      'name': 'Reykjavik',
#      'timeZone': 'Atlantic/Reykjavik'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 09:19Z',
#      'local': '2024-07-08 11:19+02:00'},
#     'revisedTime': {'utc': '2024-07-08 09:19Z',
#      'local': '2024-07-08 11:19+02:00'},
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'FPY 33G',
#    'callSign': 'FPY33G',
#    'status': 'Approaching',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TF-PLC',
#     'modeS': '4CC56D',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'FPY'}},
#   {'departure': {'airport': {'icao': 'EIDW',
#      'iata': 'DUB',
#      'name': 'Dublin',
#      'timeZone': 'Europe/Dublin'},
#     'scheduledTime': {'utc': '2024-07-08 06:50Z',
#      'local': '2024-07-08 07:50+01:00'},
#     'revisedTime': {'utc': '2024-07-08 06:50Z',
#      'local': '2024-07-08 07:50+01:00'},
#     'runwayTime': {'utc': '2024-07-08 07:33Z',
#      'local': '2024-07-08 08:33+01:00'},
#     'terminal': '1',
#     'checkInDesk': '1205-1319',
#     'gate': '113',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 09:05Z',
#      'local': '2024-07-08 11:05+02:00'},
#     'revisedTime': {'utc': '2024-07-08 09:12Z',
#      'local': '2024-07-08 11:12+02:00'},
#     'runwayTime': {'utc': '2024-07-08 09:12Z',
#      'local': '2024-07-08 11:12+02:00'},
#     'terminal': '2',
#     'gate': 'Z38',
#     'baggageBelt': 'C2',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 3669',
#    'callSign': 'RYR3TF',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-VUH', 'modeS': '4D2347', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LIRF',
#      'iata': 'FCO',
#      'name': 'Rome',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-07-08 06:55Z',
#      'local': '2024-07-08 08:55+02:00'},
#     'revisedTime': {'utc': '2024-07-08 07:18Z',
#      'local': '2024-07-08 09:18+02:00'},
#     'runwayTime': {'utc': '2024-07-08 07:18Z',
#      'local': '2024-07-08 09:18+02:00'},
#     'terminal': '1',
#     'runway': '25',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 09:05Z',
#      'local': '2024-07-08 11:05+02:00'},
#     'revisedTime': {'utc': '2024-07-08 08:58Z',
#      'local': '2024-07-08 10:58+02:00'},
#     'terminal': '2',
#     'gate': 'Z30',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 41',
#    'callSign': 'RYR83PC',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-VVA',
#     'modeS': '4D2382',
#     'model': 'Boeing 737 MAX 8'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EGLL',
#      'iata': 'LHR',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-07-08 07:55Z',
#      'local': '2024-07-08 08:55+01:00'},
#     'revisedTime': {'utc': '2024-07-08 08:34Z',
#      'local': '2024-07-08 09:34+01:00'},
#     'runwayTime': {'utc': '2024-07-08 08:35Z',
#      'local': '2024-07-08 09:35+01:00'},
#     'terminal': '5',
#     'checkInDesk': 'C',
#     'runway': '27R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 09:45Z',
#      'local': '2024-07-08 11:45+02:00'},
#     'revisedTime': {'utc': '2024-07-08 09:52Z',
#      'local': '2024-07-08 11:52+02:00'},
#     'runwayTime': {'utc': '2024-07-08 09:52Z',
#      'local': '2024-07-08 11:52+02:00'},
#     'terminal': '1',
#     'gate': 'X10',
#     'baggageBelt': 'B1',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 982',
#    'callSign': 'BAW982G',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-DBCD', 'modeS': '400B82', 'model': 'Airbus A319'},
#    'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam',
#      'timeZone': 'Europe/Amsterdam'},
#     'scheduledTime': {'utc': '2024-07-08 08:15Z',
#      'local': '2024-07-08 10:15+02:00'},
#     'revisedTime': {'utc': '2024-07-08 08:17Z',
#      'local': '2024-07-08 10:17+02:00'},
#     'runwayTime': {'utc': '2024-07-08 08:32Z',
#      'local': '2024-07-08 10:32+02:00'},
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'gate': 'D74',
#     'runway': '18L',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 09:30Z',
#      'local': '2024-07-08 11:30+02:00'},
#     'revisedTime': {'utc': '2024-07-08 09:23Z',
#      'local': '2024-07-08 11:23+02:00'},
#     'terminal': '1',
#     'gate': 'B07',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1775',
#    'callSign': 'KLM1775',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BXD',
#     'modeS': '484133',
#     'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#   {'departure': {'airport': {'icao': 'BIKF',
#      'iata': 'KEF',
#      'name': 'Reykjavik',
#      'timeZone': 'Atlantic/Reykjavik'},
#     'scheduledTime': {'utc': '2024-07-08 06:00Z',
#      'local': '2024-07-08 06:00+00:00'},
#     'revisedTime': {'utc': '2024-07-08 05:53Z',
#      'local': '2024-07-08 05:53+00:00'},
#     'runwayTime': {'utc': '2024-07-08 06:07Z',
#      'local': '2024-07-08 06:07+00:00'},
#     'gate': 'C35',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 09:30Z',
#      'local': '2024-07-08 11:30+02:00'},
#     'revisedTime': {'utc': '2024-07-08 09:20Z',
#      'local': '2024-07-08 11:20+02:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'OG 700',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TF-PLC',
#     'modeS': '4CC56D',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'Ghodawat Enterprises', 'iata': 'OG', 'icao': 'SDG'}},
#   {'departure': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2024-07-08 06:45Z',
#      'local': '2024-07-08 08:45+02:00'},
#     'revisedTime': {'utc': '2024-07-08 06:54Z',
#      'local': '2024-07-08 08:54+02:00'},
#     'runwayTime': {'utc': '2024-07-08 07:11Z',
#      'local': '2024-07-08 09:11+02:00'},
#     'terminal': 'N',
#     'checkInDesk': '019-024',
#     'gate': 'C40',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 09:45Z',
#      'local': '2024-07-08 11:45+02:00'},
#     'revisedTime': {'utc': '2024-07-08 09:21Z',
#      'local': '2024-07-08 11:21+02:00'},
#     'terminal': '1',
#     'gate': 'A35',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'SR 2413',
#    'callSign': 'SDR21YY',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ASMR', 'modeS': '3C0936', 'model': 'Airbus A320'},
#    'airline': {'name': 'SundAir', 'iata': 'SR', 'icao': 'SDR'}},
#   {'departure': {'airport': {'icao': 'LTFM',
#      'iata': 'IST',
#      'name': 'Istanbul',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-07-08 07:00Z',
#      'local': '2024-07-08 10:00+03:00'},
#     'revisedTime': {'utc': '2024-07-08 07:00Z',
#      'local': '2024-07-08 10:00+03:00'},
#     'runwayTime': {'utc': '2024-07-08 07:23Z',
#      'local': '2024-07-08 10:23+03:00'},
#     'checkInDesk': 'E-F',
#     'gate': 'F3A',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 09:45Z',
#      'local': '2024-07-08 11:45+02:00'},
#     'revisedTime': {'utc': '2024-07-08 09:37Z',
#      'local': '2024-07-08 11:37+02:00'},
#     'terminal': '1',
#     'gate': 'X01',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'TK 1729',
#    'callSign': 'THY5HW',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-JRT', 'modeS': '4BAA54', 'model': 'Airbus A321'},
#    'airline': {'name': 'Turkish', 'iata': 'TK', 'icao': 'THY'}},
#   {'departure': {'airport': {'icao': 'LGTS',
#      'iata': 'SKG',
#      'name': 'Thessaloniki',
#      'timeZone': 'Europe/Athens'},
#     'scheduledTime': {'utc': '2024-07-08 07:10Z',
#      'local': '2024-07-08 10:10+03:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 09:40Z',
#      'local': '2024-07-08 11:40+02:00'},
#     'revisedTime': {'utc': '2024-07-08 09:27Z',
#      'local': '2024-07-08 11:27+02:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5028',
#    'callSign': 'EJU68AP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IWW', 'modeS': '440B1E', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LSGG',
#      'iata': 'GVA',
#      'name': 'Geneva',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-07-08 07:25Z',
#      'local': '2024-07-08 09:25+02:00'},
#     'revisedTime': {'utc': '2024-07-08 07:25Z',
#      'local': '2024-07-08 09:25+02:00'},
#     'runwayTime': {'utc': '2024-07-08 07:36Z',
#      'local': '2024-07-08 09:36+02:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 09:10Z',
#      'local': '2024-07-08 11:10+02:00'},
#     'revisedTime': {'utc': '2024-07-08 08:51Z',
#      'local': '2024-07-08 10:51+02:00'},
#     'terminal': '1',
#     'gate': 'S02',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5182',
#    'callSign': 'EJU59XM',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IZN', 'modeS': '440CA9', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LTFJ',
#      'iata': 'SAW',
#      'name': 'Istanbul',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-07-08 06:25Z',
#      'local': '2024-07-08 09:25+03:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 09:20Z',
#      'local': '2024-07-08 11:20+02:00'},
#     'revisedTime': {'utc': '2024-07-08 09:46Z',
#      'local': '2024-07-08 11:46+02:00'},
#     'terminal': '1',
#     'gate': 'N02',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'VF 57',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-JFF', 'modeS': '4BA8C6', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ajet', 'iata': 'VF', 'icao': 'VLU'}},
#   {'departure': {'airport': {'icao': 'LTAI',
#      'iata': 'AYT',
#      'name': 'Antalya',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-07-08 06:00Z',
#      'local': '2024-07-08 09:00+03:00'},
#     'revisedTime': {'utc': '2024-07-08 06:00Z',
#      'local': '2024-07-08 09:00+03:00'},
#     'terminal': '1',
#     'checkInDesk': '126-128',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 09:35Z',
#      'local': '2024-07-08 11:35+02:00'},
#     'revisedTime': {'utc': '2024-07-08 09:28Z',
#      'local': '2024-07-08 11:28+02:00'},
#     'terminal': '1',
#     'gate': 'X07',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'XQ 160',
#    'callSign': 'SXS2SR',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-SMK',
#     'modeS': '4BCDAB',
#     'model': 'Boeing 737 MAX 8'},
#    'airline': {'name': 'Sun Express', 'iata': 'XQ', 'icao': 'SXS'}},
#   {'departure': {'airport': {'icao': 'LIPE',
#      'iata': 'BLQ',
#      'name': 'Bologna',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-07-08 08:25Z',
#      'local': '2024-07-08 10:25+02:00'},
#     'revisedTime': {'utc': '2024-07-08 08:29Z',
#      'local': '2024-07-08 10:29+02:00'},
#     'runwayTime': {'utc': '2024-07-08 08:29Z',
#      'local': '2024-07-08 10:29+02:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 10:10Z',
#      'local': '2024-07-08 12:10+02:00'},
#     'revisedTime': {'utc': '2024-07-08 09:48Z',
#      'local': '2024-07-08 11:48+02:00'},
#     'runwayTime': {'utc': '2024-07-08 09:48Z',
#      'local': '2024-07-08 11:48+02:00'},
#     'terminal': '2',
#     'gate': 'Z34',
#     'baggageBelt': 'C2',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 137',
#    'callSign': 'RYR8JN',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-QCC', 'modeS': '4D2228', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EDDM',
#      'iata': 'MUC',
#      'name': 'Munich',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-07-08 09:00Z',
#      'local': '2024-07-08 11:00+02:00'},
#     'revisedTime': {'utc': '2024-07-08 09:00Z',
#      'local': '2024-07-08 11:00+02:00'},
#     'runwayTime': {'utc': '2024-07-08 09:08Z',
#      'local': '2024-07-08 11:08+02:00'},
#     'terminal': '2',
#     'runway': '08L',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-07-08 10:05Z',
#      'local': '2024-07-08 12:05+02:00'},
#     'revisedTime': {'utc': '2024-07-08 09:54Z',
#      'local': '2024-07-08 11:54+02:00'},
#     'runwayTime': {'utc': '2024-07-08 09:53Z',
#      'local': '2024-07-08 11:53+02:00'},
#     'terminal': '1',
#     'gate': 'B17',
#     'baggageBelt': 'B4',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1926',
#    'callSign': 'DLH1926',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AISX', 'modeS': '3C6678', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}}]}

# %%
flights_json.keys()
# Out:
# dict_keys(['arrivals'])

# %%
flights_json["arrivals"]
# Out:
# [{'departure': {'airport': {'icao': 'EDDK',
#     'iata': 'CGN',
#     'name': 'Cologne',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-07-08 02:46Z',
#     'local': '2024-07-08 04:46+02:00'},
#    'revisedTime': {'utc': '2024-07-08 02:46Z',
#     'local': '2024-07-08 04:46+02:00'},
#    'runwayTime': {'utc': '2024-07-08 02:46Z',
#     'local': '2024-07-08 04:46+02:00'},
#    'runway': '06',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 03:25Z',
#     'local': '2024-07-08 05:25+02:00'},
#    'revisedTime': {'utc': '2024-07-08 03:25Z',
#     'local': '2024-07-08 05:25+02:00'},
#    'quality': ['Basic', 'Live']},
#   'number': 'DJ 6228',
#   'callSign': 'SRR6228',
#   'status': 'Approaching',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OY-SRM', 'modeS': '45CE4D', 'model': 'Boeing 767'},
#   'airline': {'name': 'Star Air A/S', 'iata': 'DJ', 'icao': 'SRR'}},
#  {'departure': {'airport': {'icao': 'UGTB',
#     'iata': 'TBS',
#     'name': 'Tbilisi',
#     'timeZone': 'Asia/Tbilisi'},
#    'scheduledTime': {'utc': '2024-07-07 23:20Z',
#     'local': '2024-07-08 03:20+04:00'},
#    'revisedTime': {'utc': '2024-07-08 00:28Z',
#     'local': '2024-07-08 04:28+04:00'},
#    'checkInDesk': '02',
#    'gate': '102',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 03:40Z',
#     'local': '2024-07-08 05:40+02:00'},
#    'revisedTime': {'utc': '2024-07-08 04:10Z',
#     'local': '2024-07-08 06:10+02:00'},
#    'terminal': '1',
#    'gate': 'X02',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8993',
#   'callSign': 'EWG8993',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-MLP', 'modeS': '4D239F', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'ZBAA',
#     'iata': 'PEK',
#     'name': 'Beijing',
#     'timeZone': 'Asia/Shanghai'},
#    'scheduledTime': {'utc': '2024-07-07 19:10Z',
#     'local': '2024-07-08 03:10+08:00'},
#    'revisedTime': {'utc': '2024-07-07 19:15Z',
#     'local': '2024-07-08 03:15+08:00'},
#    'terminal': '2',
#    'checkInDesk': 'C11-C15',
#    'gate': '08',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 04:45Z',
#     'local': '2024-07-08 06:45+02:00'},
#    'revisedTime': {'utc': '2024-07-08 04:34Z',
#     'local': '2024-07-08 06:34+02:00'},
#    'runwayTime': {'utc': '2024-07-08 04:34Z',
#     'local': '2024-07-08 06:34+02:00'},
#    'terminal': '1',
#    'gate': 'X17',
#    'baggageBelt': 'A2',
#    'runway': '25L',
#    'quality': ['Basic', 'Live']},
#   'number': 'HU 489',
#   'callSign': 'CHH489',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'B-1021', 'modeS': '7812A3', 'model': 'Airbus A330'},
#   'airline': {'name': 'Hainan', 'iata': 'HU', 'icao': 'CHH'}},
#  {'departure': {'airport': {'icao': 'EVRA',
#     'iata': 'RIX',
#     'name': 'Riga',
#     'timeZone': 'Europe/Riga'},
#    'scheduledTime': {'utc': '2024-07-08 04:00Z',
#     'local': '2024-07-08 07:00+03:00'},
#    'revisedTime': {'utc': '2024-07-08 04:00Z',
#     'local': '2024-07-08 07:00+03:00'},
#    'terminal': 'B',
#    'gate': 'B17',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 05:40Z',
#     'local': '2024-07-08 07:40+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:35Z',
#     'local': '2024-07-08 07:35+02:00'},
#    'runwayTime': {'utc': '2024-07-08 05:35Z',
#     'local': '2024-07-08 07:35+02:00'},
#    'terminal': '1',
#    'gate': 'A33',
#    'baggageBelt': 'A4',
#    'runway': '25L',
#    'quality': ['Basic', 'Live']},
#   'number': 'BT 211',
#   'callSign': 'BTI74A',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'YL-ABP', 'modeS': '502D7A', 'model': 'Airbus A220-300'},
#   'airline': {'name': 'airBaltic', 'iata': 'BT', 'icao': 'BTI'}},
#  {'departure': {'airport': {'icao': 'EVRA',
#     'iata': 'RIX',
#     'name': 'Riga',
#     'timeZone': 'Europe/Riga'},
#    'scheduledTime': {'utc': '2024-07-08 04:00Z',
#     'local': '2024-07-08 07:00+03:00'},
#    'revisedTime': {'utc': '2024-07-08 04:00Z',
#     'local': '2024-07-08 07:00+03:00'},
#    'terminal': 'B',
#    'gate': 'B17',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 05:40Z',
#     'local': '2024-07-08 07:40+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:35Z',
#     'local': '2024-07-08 07:35+02:00'},
#    'terminal': '1',
#    'gate': 'A33',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'DL 7313',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'YL-ABP', 'modeS': '502D7A', 'model': 'Airbus A220-300'},
#   'airline': {'name': 'Delta Air Lines', 'iata': 'DL', 'icao': 'DAL'}},
#  {'departure': {'airport': {'icao': 'KJFK',
#     'iata': 'JFK',
#     'name': 'New York',
#     'timeZone': 'America/New_York'},
#    'scheduledTime': {'utc': '2024-07-07 21:45Z',
#     'local': '2024-07-07 17:45-04:00'},
#    'revisedTime': {'utc': '2024-07-07 22:10Z',
#     'local': '2024-07-07 18:10-04:00'},
#    'runwayTime': {'utc': '2024-07-07 22:10Z',
#     'local': '2024-07-07 18:10-04:00'},
#    'terminal': '4',
#    'runway': '13R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 05:50Z',
#     'local': '2024-07-08 07:50+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:06Z',
#     'local': '2024-07-08 07:06+02:00'},
#    'runwayTime': {'utc': '2024-07-08 05:06Z',
#     'local': '2024-07-08 07:06+02:00'},
#    'terminal': '1',
#    'gate': 'Y02',
#    'baggageBelt': 'B3',
#    'runway': '25L',
#    'quality': ['Basic', 'Live']},
#   'number': 'DL 92',
#   'callSign': 'DAL92',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'N177DZ', 'modeS': 'A13391', 'model': 'Boeing 767-300'},
#   'airline': {'name': 'Delta Air Lines', 'iata': 'DL', 'icao': 'DAL'}},
#  {'departure': {'airport': {'icao': 'EDDR',
#     'iata': 'SCN',
#     'name': 'Saarbrücken',
#     'timeZone': 'Europe/Berlin'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 05:42Z',
#     'local': '2024-07-08 07:42+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:42Z',
#     'local': '2024-07-08 07:42+02:00'},
#    'runwayTime': {'utc': '2024-07-08 05:42Z',
#     'local': '2024-07-08 07:42+02:00'},
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'DMS 2PV',
#   'callSign': 'DMS2PV',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OY-RUO', 'modeS': '45CAAF', 'model': 'ATR 42'},
#   'airline': {'name': 'DMS'}},
#  {'departure': {'airport': {'icao': 'EDDK',
#     'iata': 'CGN',
#     'name': 'Cologne',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-07-08 04:30Z',
#     'local': '2024-07-08 06:30+02:00'},
#    'terminal': '1',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 05:40Z',
#     'local': '2024-07-08 07:40+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:24Z',
#     'local': '2024-07-08 07:24+02:00'},
#    'terminal': '1',
#    'gate': 'B06',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 12',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-ABZL', 'modeS': '3C4B4C', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EDDS',
#     'iata': 'STR',
#     'name': 'Stuttgart',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-07-08 04:15Z',
#     'local': '2024-07-08 06:15+02:00'},
#    'revisedTime': {'utc': '2024-07-08 04:15Z',
#     'local': '2024-07-08 06:15+02:00'},
#    'terminal': '3',
#    'gate': '140',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 05:25Z',
#     'local': '2024-07-08 07:25+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:18Z',
#     'local': '2024-07-08 07:18+02:00'},
#    'terminal': '1',
#    'gate': 'A36',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 2002',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-ABGQ', 'modeS': '3C48F1', 'model': 'Airbus A319'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'LTAJ',
#     'iata': 'GZT',
#     'name': 'Gaziantep',
#     'timeZone': 'Europe/Istanbul'},
#    'scheduledTime': {'utc': '2024-07-08 00:55Z',
#     'local': '2024-07-08 03:55+03:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 04:45Z',
#     'local': '2024-07-08 06:45+02:00'},
#    'revisedTime': {'utc': '2024-07-08 04:41Z',
#     'local': '2024-07-08 06:41+02:00'},
#    'terminal': '1',
#    'gate': 'N02',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'XQ 1766',
#   'callSign': 'SXS1ZP',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-SPA', 'modeS': '4BCE01', 'model': 'Boeing 737'},
#   'airline': {'name': 'Sun Express', 'iata': 'XQ', 'icao': 'SXS'}},
#  {'departure': {'airport': {'icao': 'LTBJ',
#     'iata': 'ADB',
#     'name': 'İzmir',
#     'timeZone': 'Europe/Istanbul'},
#    'scheduledTime': {'utc': '2024-07-08 01:25Z',
#     'local': '2024-07-08 04:25+03:00'},
#    'revisedTime': {'utc': '2024-07-08 01:34Z',
#     'local': '2024-07-08 04:34+03:00'},
#    'runwayTime': {'utc': '2024-07-08 01:37Z',
#     'local': '2024-07-08 04:37+03:00'},
#    'checkInDesk': '08',
#    'gate': '111',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 04:30Z',
#     'local': '2024-07-08 06:30+02:00'},
#    'revisedTime': {'utc': '2024-07-08 04:05Z',
#     'local': '2024-07-08 06:05+02:00'},
#    'terminal': '1',
#    'gate': 'X01',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'XQ 966',
#   'callSign': 'SXS5D',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-SRB', 'modeS': '4BCE42', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Sun Express', 'iata': 'XQ', 'icao': 'SXS'}},
#  {'departure': {'airport': {'icao': 'EVRA',
#     'iata': 'RIX',
#     'name': 'Riga',
#     'timeZone': 'Europe/Riga'},
#    'scheduledTime': {'utc': '2024-07-08 04:00Z',
#     'local': '2024-07-08 07:00+03:00'},
#    'revisedTime': {'utc': '2024-07-08 04:00Z',
#     'local': '2024-07-08 07:00+03:00'},
#    'terminal': 'B',
#    'gate': 'B17',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 05:40Z',
#     'local': '2024-07-08 07:40+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:35Z',
#     'local': '2024-07-08 07:35+02:00'},
#    'terminal': '1',
#    'gate': 'A33',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'A3 3219',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'YL-ABP', 'modeS': '502D7A', 'model': 'Airbus A220-300'},
#   'airline': {'name': 'Aegean', 'iata': 'A3', 'icao': 'AEE'}},
#  {'departure': {'airport': {'icao': 'EDDL',
#     'iata': 'DUS',
#     'name': 'Duesseldorf',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-07-08 04:20Z',
#     'local': '2024-07-08 06:20+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:03Z',
#     'local': '2024-07-08 07:03+02:00'},
#    'runwayTime': {'utc': '2024-07-08 05:09Z',
#     'local': '2024-07-08 07:09+02:00'},
#    'terminal': 'B',
#    'checkInDesk': '151,170',
#    'gate': 'A54',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 05:30Z',
#     'local': '2024-07-08 07:30+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:55Z',
#     'local': '2024-07-08 07:55+02:00'},
#    'terminal': '1',
#    'gate': 'B20',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 9048',
#   'callSign': 'GWI52FP',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AGWG', 'modeS': '3C5EE7', 'model': 'Airbus A319'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EYVI',
#     'iata': 'VNO',
#     'name': 'Vilnius',
#     'timeZone': 'Europe/Vilnius'},
#    'scheduledTime': {'utc': '2024-07-08 04:10Z',
#     'local': '2024-07-08 07:10+03:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 05:50Z',
#     'local': '2024-07-08 07:50+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:40Z',
#     'local': '2024-07-08 07:40+02:00'},
#    'runwayTime': {'utc': '2024-07-08 05:40Z',
#     'local': '2024-07-08 07:40+02:00'},
#    'terminal': '2',
#    'gate': 'Z32',
#    'baggageBelt': 'C3',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 1571',
#   'callSign': 'RYR16HT',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'SP-RSL', 'modeS': '48C22B', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'EVRA',
#     'iata': 'RIX',
#     'name': 'Riga',
#     'timeZone': 'Europe/Riga'},
#    'scheduledTime': {'utc': '2024-07-08 04:00Z',
#     'local': '2024-07-08 07:00+03:00'},
#    'revisedTime': {'utc': '2024-07-08 04:00Z',
#     'local': '2024-07-08 07:00+03:00'},
#    'terminal': 'B',
#    'gate': 'B17',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 05:40Z',
#     'local': '2024-07-08 07:40+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:35Z',
#     'local': '2024-07-08 07:35+02:00'},
#    'terminal': '1',
#    'gate': 'A33',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'JU 7659',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'YL-ABP', 'modeS': '502D7A', 'model': 'Airbus A220-300'},
#   'airline': {'name': 'JU'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-07-08 04:45Z',
#     'local': '2024-07-08 06:45+02:00'},
#    'revisedTime': {'utc': '2024-07-08 04:45Z',
#     'local': '2024-07-08 06:45+02:00'},
#    'runwayTime': {'utc': '2024-07-08 05:10Z',
#     'local': '2024-07-08 07:10+02:00'},
#    'terminal': '1',
#    'checkInDesk': '259-335',
#    'gate': 'A23',
#    'runway': '25C',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 05:55Z',
#     'local': '2024-07-08 07:55+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:52Z',
#     'local': '2024-07-08 07:52+02:00'},
#    'terminal': '1',
#    'gate': 'A02',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 170',
#   'callSign': 'DLH1PT',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIUC',
#    'modeS': '3C66A3',
#    'model': 'Airbus A320 (Sharklets)'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-07-08 04:15Z',
#     'local': '2024-07-08 06:15+02:00'},
#    'revisedTime': {'utc': '2024-07-08 04:15Z',
#     'local': '2024-07-08 06:15+02:00'},
#    'terminal': '1',
#    'checkInDesk': '259-335',
#    'gate': 'A52',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 05:25Z',
#     'local': '2024-07-08 07:25+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:14Z',
#     'local': '2024-07-08 07:14+02:00'},
#    'terminal': '1',
#    'gate': 'B03',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 172',
#   'callSign': 'DLH172',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIDA', 'modeS': '3C6481', 'model': 'Airbus A321'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'EDDS',
#     'iata': 'STR',
#     'name': 'Stuttgart',
#     'timeZone': 'Europe/Berlin'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 05:25Z',
#     'local': '2024-07-08 07:25+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:18Z',
#     'local': '2024-07-08 07:18+02:00'},
#    'terminal': '1',
#    'gate': 'A36',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 5385',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-ABGQ', 'modeS': '3C48F1', 'model': 'Airbus A319'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'OTHH',
#     'iata': 'DOH',
#     'name': 'Doha',
#     'timeZone': 'Asia/Qatar'},
#    'scheduledTime': {'utc': '2024-07-07 23:20Z',
#     'local': '2024-07-08 02:20+03:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 05:20Z',
#     'local': '2024-07-08 07:20+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:10Z',
#     'local': '2024-07-08 07:10+02:00'},
#    'runwayTime': {'utc': '2024-07-08 05:10Z',
#     'local': '2024-07-08 07:10+02:00'},
#    'terminal': '1',
#    'gate': 'X07',
#    'baggageBelt': 'A3',
#    'runway': '25L',
#    'quality': ['Basic', 'Live']},
#   'number': 'QR 79',
#   'callSign': 'QTR32A',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'A7-BHN', 'modeS': '06A2F1', 'model': 'Boeing 787-9'},
#   'airline': {'name': 'Qatar Airways', 'iata': 'QR', 'icao': 'QTR'}},
#  {'departure': {'airport': {'icao': 'KEWR',
#     'iata': 'EWR',
#     'name': 'Newark',
#     'timeZone': 'America/New_York'},
#    'scheduledTime': {'utc': '2024-07-07 21:05Z',
#     'local': '2024-07-07 17:05-04:00'},
#    'revisedTime': {'utc': '2024-07-07 21:47Z',
#     'local': '2024-07-07 17:47-04:00'},
#    'runwayTime': {'utc': '2024-07-07 21:47Z',
#     'local': '2024-07-07 17:47-04:00'},
#    'terminal': 'C',
#    'runway': '04L',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 05:15Z',
#     'local': '2024-07-08 07:15+02:00'},
#    'revisedTime': {'utc': '2024-07-08 04:49Z',
#     'local': '2024-07-08 06:49+02:00'},
#    'terminal': '1',
#    'gate': 'Y17',
#    'baggageBelt': 'B2',
#    'quality': ['Basic', 'Live']},
#   'number': 'UA 962',
#   'callSign': 'UAL962',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'N69063', 'modeS': 'A92DFC', 'model': 'Boeing 767-400'},
#   'airline': {'name': 'United', 'iata': 'UA', 'icao': 'UAL'}},
#  {'departure': {'airport': {'icao': 'LFPG',
#     'iata': 'CDG',
#     'name': 'Paris',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-07-08 05:00Z',
#     'local': '2024-07-08 07:00+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:18Z',
#     'local': '2024-07-08 07:18+02:00'},
#    'runwayTime': {'utc': '2024-07-08 05:18Z',
#     'local': '2024-07-08 07:18+02:00'},
#    'terminal': '2F',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 06:40Z',
#     'local': '2024-07-08 08:40+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:30Z',
#     'local': '2024-07-08 08:30+02:00'},
#    'terminal': '1',
#    'gate': 'B06',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'AF 1434',
#   'callSign': 'AFR95ZE',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'F-HDRF', 'modeS': '398E25', 'model': 'Airbus A320'},
#   'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#  {'departure': {'airport': {'icao': 'EFHK',
#     'iata': 'HEL',
#     'name': 'Helsinki',
#     'timeZone': 'Europe/Helsinki'},
#    'scheduledTime': {'utc': '2024-07-08 04:05Z',
#     'local': '2024-07-08 07:05+03:00'},
#    'revisedTime': {'utc': '2024-07-08 04:04Z',
#     'local': '2024-07-08 07:04+03:00'},
#    'runwayTime': {'utc': '2024-07-08 04:15Z',
#     'local': '2024-07-08 07:15+03:00'},
#    'terminal': '2',
#    'checkInDesk': '211',
#    'gate': '30',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 06:05Z',
#     'local': '2024-07-08 08:05+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:59Z',
#     'local': '2024-07-08 07:59+02:00'},
#    'terminal': '1',
#    'gate': 'A30',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'AY 1431',
#   'callSign': 'FIN3AW',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OH-LZH',
#    'modeS': '461F9D',
#    'model': 'Airbus A321 (Sharklets)'},
#   'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#  {'departure': {'airport': {'icao': 'EDDR',
#     'iata': 'SCN',
#     'name': 'Saarbrücken',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-07-08 04:30Z',
#     'local': '2024-07-08 06:30+02:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 06:05Z',
#     'local': '2024-07-08 08:05+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:43Z',
#     'local': '2024-07-08 07:43+02:00'},
#    'terminal': '2',
#    'gate': 'Z36',
#    'baggageBelt': 'C2',
#    'quality': ['Basic', 'Live']},
#   'number': 'DX 121',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OY-RUO', 'modeS': '45CAAF', 'model': 'ATR 42'},
#   'airline': {'name': 'Danish Air', 'iata': 'DX', 'icao': 'DTR'}},
#  {'departure': {'airport': {'icao': 'ENGM',
#     'iata': 'OSL',
#     'name': 'Oslo',
#     'timeZone': 'Europe/Oslo'},
#    'scheduledTime': {'utc': '2024-07-08 05:00Z',
#     'local': '2024-07-08 07:00+02:00'},
#    'revisedTime': {'utc': '2024-07-08 04:54Z',
#     'local': '2024-07-08 06:54+02:00'},
#    'runwayTime': {'utc': '2024-07-08 05:07Z',
#     'local': '2024-07-08 07:07+02:00'},
#    'checkInDesk': '123',
#    'gate': 'D4',
#    'runway': '19L',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 06:35Z',
#     'local': '2024-07-08 08:35+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:25Z',
#     'local': '2024-07-08 08:25+02:00'},
#    'terminal': '2',
#    'gate': 'Z34',
#    'baggageBelt': 'C2',
#    'quality': ['Basic', 'Live']},
#   'number': 'DY 1100',
#   'callSign': 'NOZ1100',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'LN-DYR', 'modeS': '47875C', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Norwegian Air Shuttle', 'iata': 'DY', 'icao': 'NOZ'}},
#  {'departure': {'airport': {'icao': 'LIML',
#     'iata': 'LIN',
#     'name': 'Milan',
#     'timeZone': 'Europe/Rome'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 06:35Z',
#     'local': '2024-07-08 08:35+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:27Z',
#     'local': '2024-07-08 08:27+02:00'},
#    'terminal': '1',
#    'gate': 'A34',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5068',
#   'callSign': 'EJU5068',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-ICL',
#    'modeS': '4404A4',
#    'model': 'Airbus A320 (Sharklets)'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'EKCH',
#     'iata': 'CPH',
#     'name': 'Copenhagen',
#     'timeZone': 'Europe/Copenhagen'},
#    'scheduledTime': {'utc': '2024-07-08 05:50Z',
#     'local': '2024-07-08 07:50+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:50Z',
#     'local': '2024-07-08 07:50+02:00'},
#    'runwayTime': {'utc': '2024-07-08 05:53Z',
#     'local': '2024-07-08 07:53+02:00'},
#    'terminal': 'erminal2',
#    'gate': 'F7',
#    'runway': '22R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 06:55Z',
#     'local': '2024-07-08 08:55+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:34Z',
#     'local': '2024-07-08 08:34+02:00'},
#    'terminal': '1',
#    'gate': 'A32',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5262',
#   'callSign': 'EJU48QZ',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IDS', 'modeS': '440DA5', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'ESSA',
#     'iata': 'ARN',
#     'name': 'Stockholm',
#     'timeZone': 'Europe/Stockholm'},
#    'scheduledTime': {'utc': '2024-07-08 04:30Z',
#     'local': '2024-07-08 06:30+02:00'},
#    'revisedTime': {'utc': '2024-07-08 04:36Z',
#     'local': '2024-07-08 06:36+02:00'},
#    'runwayTime': {'utc': '2024-07-08 04:48Z',
#     'local': '2024-07-08 06:48+02:00'},
#    'terminal': '5',
#    'checkInDesk': '25-27',
#    'gate': 'C43',
#    'runway': '19R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 06:05Z',
#     'local': '2024-07-08 08:05+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:05Z',
#     'local': '2024-07-08 08:05+02:00'},
#    'runwayTime': {'utc': '2024-07-08 06:05Z',
#     'local': '2024-07-08 08:05+02:00'},
#    'terminal': '1',
#    'gate': 'A38',
#    'baggageBelt': 'A1',
#    'runway': '25L',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 4600',
#   'callSign': 'EWG4600',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-EUR', 'modeS': '4D2406', 'model': 'Airbus A320-200'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'LCPH',
#     'iata': 'PFO',
#     'name': 'Paphos',
#     'timeZone': 'Asia/Nicosia'},
#    'scheduledTime': {'utc': '2024-07-08 03:00Z',
#     'local': '2024-07-08 06:00+03:00'},
#    'revisedTime': {'utc': '2024-07-08 03:24Z',
#     'local': '2024-07-08 06:24+03:00'},
#    'runwayTime': {'utc': '2024-07-08 03:24Z',
#     'local': '2024-07-08 06:24+03:00'},
#    'runway': '29',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 06:45Z',
#     'local': '2024-07-08 08:45+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:43Z',
#     'local': '2024-07-08 08:43+02:00'},
#    'terminal': '2',
#    'gate': 'Z38',
#    'baggageBelt': 'C3',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 354',
#   'callSign': 'RYR354',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EI-IHB',
#    'modeS': '4CADE7',
#    'model': 'Boeing 737 MAX 8'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'LYBE',
#     'iata': 'BEG',
#     'name': 'Belgrade',
#     'timeZone': 'Europe/Belgrade'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 06:40Z',
#     'local': '2024-07-08 08:40+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:45Z',
#     'local': '2024-07-08 08:45+02:00'},
#    'terminal': '1',
#    'gate': 'X17',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'JA 354',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'YU-APL', 'modeS': '4C01EB', 'model': 'Airbus A319'},
#   'airline': {'name': 'JetSMART', 'iata': 'JA', 'icao': 'JAT'}},
#  {'departure': {'airport': {'icao': 'LYBE',
#     'iata': 'BEG',
#     'name': 'Belgrade',
#     'timeZone': 'Europe/Belgrade'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 06:51Z',
#     'local': '2024-07-08 08:51+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:51Z',
#     'local': '2024-07-08 08:51+02:00'},
#    'runwayTime': {'utc': '2024-07-08 06:45Z',
#     'local': '2024-07-08 08:45+02:00'},
#    'runway': '25L',
#    'quality': ['Basic', 'Live']},
#   'number': 'JU 37H',
#   'callSign': 'ASL37H',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'YU-APL', 'modeS': '4C01EB', 'model': 'Airbus A319'},
#   'airline': {'name': 'Air Serbia', 'iata': 'JU', 'icao': 'ASL'}},
#  {'departure': {'airport': {'icao': 'ELLX',
#     'iata': 'LUX',
#     'name': 'Luxembourg',
#     'timeZone': 'Europe/Luxembourg'},
#    'scheduledTime': {'utc': '2024-07-08 04:35Z',
#     'local': '2024-07-08 06:35+02:00'},
#    'revisedTime': {'utc': '2024-07-08 04:35Z',
#     'local': '2024-07-08 06:35+02:00'},
#    'runwayTime': {'utc': '2024-07-08 04:59Z',
#     'local': '2024-07-08 06:59+02:00'},
#    'terminal': 'A',
#    'gate': 'B04',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 06:05Z',
#     'local': '2024-07-08 08:05+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:10Z',
#     'local': '2024-07-08 08:10+02:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B2',
#    'quality': ['Basic', 'Live']},
#   'number': 'LG 9471',
#   'callSign': 'LGL91B',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'LX-LGE',
#    'modeS': '4D00C6',
#    'model': 'De Havilland Canada DHC-8-400 Dash 8Q'},
#   'airline': {'name': 'Luxair', 'iata': 'LG', 'icao': 'LGL'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-07-08 05:45Z',
#     'local': '2024-07-08 07:45+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:45Z',
#     'local': '2024-07-08 07:45+02:00'},
#    'terminal': '1',
#    'checkInDesk': '259-335',
#    'gate': 'A13',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 06:55Z',
#     'local': '2024-07-08 08:55+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:57Z',
#     'local': '2024-07-08 08:57+02:00'},
#    'runwayTime': {'utc': '2024-07-08 06:56Z',
#     'local': '2024-07-08 08:56+02:00'},
#    'terminal': '1',
#    'gate': 'B03',
#    'baggageBelt': 'B4',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 174',
#   'callSign': 'DLH4PH',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIBG', 'modeS': '3C6447', 'model': 'Airbus A319'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'ESSA',
#     'iata': 'ARN',
#     'name': 'Stockholm',
#     'timeZone': 'Europe/Stockholm'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 06:05Z',
#     'local': '2024-07-08 08:05+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:05Z',
#     'local': '2024-07-08 08:05+02:00'},
#    'terminal': '1',
#    'gate': 'A38',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 5344',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-EUR', 'model': 'Airbus A320-200'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'LSZH',
#     'iata': 'ZRH',
#     'name': 'Zurich',
#     'timeZone': 'Europe/Zurich'},
#    'scheduledTime': {'utc': '2024-07-08 05:20Z',
#     'local': '2024-07-08 07:20+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:30Z',
#     'local': '2024-07-08 07:30+02:00'},
#    'runwayTime': {'utc': '2024-07-08 05:43Z',
#     'local': '2024-07-08 07:43+02:00'},
#    'checkInDesk': '1',
#    'gate': 'B31',
#    'runway': '28',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 06:45Z',
#     'local': '2024-07-08 08:45+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:49Z',
#     'local': '2024-07-08 08:49+02:00'},
#    'runwayTime': {'utc': '2024-07-08 06:50Z',
#     'local': '2024-07-08 08:50+02:00'},
#    'terminal': '1',
#    'gate': 'B07',
#    'baggageBelt': 'B1',
#    'runway': '25L',
#    'quality': ['Basic', 'Live']},
#   'number': 'LX 974',
#   'callSign': 'SWR97Y',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'YL-ABM', 'modeS': '502D5E', 'model': 'Airbus A220-300'},
#   'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#  {'departure': {'airport': {'icao': 'LOWW',
#     'iata': 'VIE',
#     'name': 'Vienna',
#     'timeZone': 'Europe/Vienna'},
#    'scheduledTime': {'utc': '2024-07-08 05:00Z',
#     'local': '2024-07-08 07:00+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:08Z',
#     'local': '2024-07-08 07:08+02:00'},
#    'runwayTime': {'utc': '2024-07-08 05:09Z',
#     'local': '2024-07-08 07:09+02:00'},
#    'terminal': '3',
#    'checkInDesk': '351-372',
#    'gate': 'F25',
#    'runway': '34',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 06:10Z',
#     'local': '2024-07-08 08:10+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:56Z',
#     'local': '2024-07-08 07:56+02:00'},
#    'terminal': '1',
#    'gate': 'A06',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'OS 223',
#   'callSign': 'AUA223',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LXE', 'modeS': '4402A3', 'model': 'Airbus A320'},
#   'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#  {'departure': {'airport': {'icao': 'LTAI',
#     'iata': 'AYT',
#     'name': 'Antalya',
#     'timeZone': 'Europe/Istanbul'},
#    'scheduledTime': {'utc': '2024-07-08 03:05Z',
#     'local': '2024-07-08 06:05+03:00'},
#    'revisedTime': {'utc': '2024-07-08 04:00Z',
#     'local': '2024-07-08 07:00+03:00'},
#    'terminal': '1',
#    'checkInDesk': '107-109',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 06:35Z',
#     'local': '2024-07-08 08:35+02:00'},
#    'revisedTime': {'utc': '2024-07-08 07:43Z',
#     'local': '2024-07-08 09:43+02:00'},
#    'terminal': '1',
#    'gate': 'N02',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'PC 5067',
#   'callSign': 'PGT4WR',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-NCM', 'modeS': '4BB86D', 'model': 'Airbus A320 NEO'},
#   'airline': {'name': 'Pegasus', 'iata': 'PC', 'icao': 'PGT'}},
#  {'departure': {'airport': {'icao': 'HEMA',
#     'iata': 'RMF',
#     'name': 'Marsa Alam',
#     'timeZone': 'Africa/Cairo'},
#    'scheduledTime': {'utc': '2024-07-08 01:10Z',
#     'local': '2024-07-08 04:10+03:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 06:10Z',
#     'local': '2024-07-08 08:10+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:26Z',
#     'local': '2024-07-08 07:26+02:00'},
#    'terminal': '1',
#    'gate': 'N02',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'SM 2962',
#   'callSign': 'MSC2962',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'SU-BUK', 'modeS': '01022C', 'model': 'Airbus A320 NEO'},
#   'airline': {'name': 'Air Cairo', 'iata': 'SM', 'icao': 'MSC'}},
#  {'departure': {'airport': {'icao': 'LIML',
#     'iata': 'LIN',
#     'name': 'Milan',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-07-08 04:55Z',
#     'local': '2024-07-08 06:55+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:12Z',
#     'local': '2024-07-08 07:12+02:00'},
#    'runwayTime': {'utc': '2024-07-08 05:12Z',
#     'local': '2024-07-08 07:12+02:00'},
#    'runway': '36',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 06:35Z',
#     'local': '2024-07-08 08:35+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:27Z',
#     'local': '2024-07-08 08:27+02:00'},
#    'terminal': '1',
#    'gate': 'A34',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5068',
#   'callSign': 'EZY5068',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-ICL',
#    'modeS': '4404A4',
#    'model': 'Airbus A320 (Sharklets)'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'EKCH',
#     'iata': 'CPH',
#     'name': 'Copenhagen',
#     'timeZone': 'Europe/Copenhagen'},
#    'scheduledTime': {'utc': '2024-07-08 05:50Z',
#     'local': '2024-07-08 07:50+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:50Z',
#     'local': '2024-07-08 07:50+02:00'},
#    'runwayTime': {'utc': '2024-07-08 05:53Z',
#     'local': '2024-07-08 07:53+02:00'},
#    'terminal': 'erminal2',
#    'gate': 'F7',
#    'runway': '22R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 06:55Z',
#     'local': '2024-07-08 08:55+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:34Z',
#     'local': '2024-07-08 08:34+02:00'},
#    'terminal': '1',
#    'gate': 'A32',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5262',
#   'callSign': 'EJU48QZ',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IDS', 'modeS': '440DA5', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LFST',
#     'iata': 'SXB',
#     'name': 'Strasbourg',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-07-08 04:30Z',
#     'local': '2024-07-08 06:30+02:00'},
#    'revisedTime': {'utc': '2024-07-08 04:36Z',
#     'local': '2024-07-08 06:36+02:00'},
#    'runwayTime': {'utc': '2024-07-08 04:36Z',
#     'local': '2024-07-08 06:36+02:00'},
#    'runway': '23',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 06:00Z',
#     'local': '2024-07-08 08:00+02:00'},
#    'revisedTime': {'utc': '2024-07-08 05:33Z',
#     'local': '2024-07-08 07:33+02:00'},
#    'runwayTime': {'utc': '2024-07-08 05:33Z',
#     'local': '2024-07-08 07:33+02:00'},
#    'terminal': '1',
#    'gate': 'A35',
#    'baggageBelt': 'A2',
#    'runway': '25L',
#    'quality': ['Basic', 'Live']},
#   'number': 'V7 2596',
#   'callSign': 'VOE2UD',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EC-NPC', 'modeS': '346648', 'model': 'Airbus A320'},
#   'airline': {'name': 'Volotea', 'iata': 'V7', 'icao': 'VOE'}},
#  {'departure': {'airport': {'icao': 'DTTA',
#     'iata': 'TUN',
#     'name': 'Tunis',
#     'timeZone': 'Africa/Tunis'},
#    'scheduledTime': {'utc': '2024-07-08 05:00Z',
#     'local': '2024-07-08 06:00+01:00'},
#    'terminal': 'M',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 07:45Z',
#     'local': '2024-07-08 09:45+02:00'},
#    'revisedTime': {'utc': '2024-07-08 07:35Z',
#     'local': '2024-07-08 09:35+02:00'},
#    'terminal': '1',
#    'gate': 'N02',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'BJ 232',
#   'callSign': 'LBT232',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TS-ING',
#    'modeS': '02A1A6',
#    'model': 'Airbus A320-200 (sharklets)'},
#   'airline': {'name': 'Nouvelair Tunisie', 'iata': 'BJ', 'icao': 'LBT'}},
#  {'departure': {'airport': {'icao': 'LSZH',
#     'iata': 'ZRH',
#     'name': 'Zurich',
#     'timeZone': 'Europe/Zurich'},
#    'scheduledTime': {'utc': '2024-07-08 06:05Z',
#     'local': '2024-07-08 08:05+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:00Z',
#     'local': '2024-07-08 08:00+02:00'},
#    'checkInDesk': '3',
#    'gate': 'A84',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 07:40Z',
#     'local': '2024-07-08 09:40+02:00'},
#    'revisedTime': {'utc': '2024-07-08 07:34Z',
#     'local': '2024-07-08 09:34+02:00'},
#    'terminal': '1',
#    'gate': 'A33',
#    'baggageBelt': 'A3',
#    'runway': '25L',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5188',
#   'callSign': 'EJU73MR',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IDD', 'modeS': '440CCC', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'EDDS',
#     'iata': 'STR',
#     'name': 'Stuttgart',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-07-08 06:35Z',
#     'local': '2024-07-08 08:35+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:35Z',
#     'local': '2024-07-08 08:35+02:00'},
#    'terminal': '3',
#    'gate': '140',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 07:45Z',
#     'local': '2024-07-08 09:45+02:00'},
#    'revisedTime': {'utc': '2024-07-08 08:55Z',
#     'local': '2024-07-08 10:55+02:00'},
#    'terminal': '1',
#    'gate': 'A38',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8001',
#   'callSign': 'EWG8001',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-MLZ', 'modeS': '4D2494', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EDDL',
#     'iata': 'DUS',
#     'name': 'Duesseldorf',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-07-08 06:15Z',
#     'local': '2024-07-08 08:15+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:15Z',
#     'local': '2024-07-08 08:15+02:00'},
#    'runwayTime': {'utc': '2024-07-08 06:24Z',
#     'local': '2024-07-08 08:24+02:00'},
#    'terminal': 'B',
#    'checkInDesk': '151,170',
#    'gate': 'A25',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 07:25Z',
#     'local': '2024-07-08 09:25+02:00'},
#    'revisedTime': {'utc': '2024-07-08 07:14Z',
#     'local': '2024-07-08 09:14+02:00'},
#    'terminal': '1',
#    'gate': 'A37',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8041',
#   'callSign': 'GWI9XL',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AGWK', 'modeS': '3C5EEB', 'model': 'Airbus A319'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EDDK',
#     'iata': 'CGN',
#     'name': 'Cologne',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-07-08 06:15Z',
#     'local': '2024-07-08 08:15+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:50Z',
#     'local': '2024-07-08 08:50+02:00'},
#    'runwayTime': {'utc': '2024-07-08 06:50Z',
#     'local': '2024-07-08 08:50+02:00'},
#    'terminal': '1',
#    'runway': '14L',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 07:25Z',
#     'local': '2024-07-08 09:25+02:00'},
#    'revisedTime': {'utc': '2024-07-08 07:37Z',
#     'local': '2024-07-08 09:37+02:00'},
#    'terminal': '1',
#    'gate': 'A35',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8059',
#   'callSign': 'EWG9RX',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-MLP', 'modeS': '4D239F', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EGSS',
#     'iata': 'STN',
#     'name': 'London',
#     'timeZone': 'Europe/London'},
#    'scheduledTime': {'utc': '2024-07-08 05:30Z',
#     'local': '2024-07-08 06:30+01:00'},
#    'revisedTime': {'utc': '2024-07-08 05:40Z',
#     'local': '2024-07-08 06:40+01:00'},
#    'runwayTime': {'utc': '2024-07-08 06:00Z',
#     'local': '2024-07-08 07:00+01:00'},
#    'terminal': '1',
#    'gate': '37',
#    'runway': '22',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 07:15Z',
#     'local': '2024-07-08 09:15+02:00'},
#    'revisedTime': {'utc': '2024-07-08 07:15Z',
#     'local': '2024-07-08 09:15+02:00'},
#    'terminal': '2',
#    'gate': 'Z40',
#    'baggageBelt': 'C2',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 145',
#   'callSign': 'RYR927E',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EI-EXF', 'modeS': '4CAA61', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'EGPH',
#     'iata': 'EDI',
#     'name': 'Edinburgh',
#     'timeZone': 'Europe/London'},
#    'scheduledTime': {'utc': '2024-07-08 05:00Z',
#     'local': '2024-07-08 06:00+01:00'},
#    'revisedTime': {'utc': '2024-07-08 05:14Z',
#     'local': '2024-07-08 06:14+01:00'},
#    'runwayTime': {'utc': '2024-07-08 05:16Z',
#     'local': '2024-07-08 06:16+01:00'},
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 07:00Z',
#     'local': '2024-07-08 09:00+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:51Z',
#     'local': '2024-07-08 08:51+02:00'},
#    'runwayTime': {'utc': '2024-07-08 06:51Z',
#     'local': '2024-07-08 08:51+02:00'},
#    'terminal': '2',
#    'gate': 'Z44',
#    'baggageBelt': 'C1',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 2376',
#   'callSign': 'RYR2376',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EI-IHV',
#    'modeS': '4CAE48',
#    'model': 'Boeing 737 MAX 8'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'UGKO',
#     'iata': 'KUT',
#     'name': 'Kutaisi',
#     'timeZone': 'Asia/Tbilisi'},
#    'scheduledTime': {'utc': '2024-07-08 02:20Z',
#     'local': '2024-07-08 06:20+04:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 06:30Z',
#     'local': '2024-07-08 08:30+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:07Z',
#     'local': '2024-07-08 08:07+02:00'},
#    'terminal': '1',
#    'gate': 'N02',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'W6 7909',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'HA-LGN', 'model': 'Airbus A321 NEO'},
#   'airline': {'name': 'Wizz Air', 'iata': 'W6', 'icao': 'WZZ'}},
#  {'departure': {'airport': {'icao': 'EDDL',
#     'iata': 'DUS',
#     'name': 'Duesseldorf',
#     'timeZone': 'Europe/Berlin'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 07:26Z',
#     'local': '2024-07-08 09:26+02:00'},
#    'revisedTime': {'utc': '2024-07-08 07:26Z',
#     'local': '2024-07-08 09:26+02:00'},
#    'runwayTime': {'utc': '2024-07-08 07:13Z',
#     'local': '2024-07-08 09:13+02:00'},
#    'runway': '25L',
#    'quality': ['Basic', 'Live']},
#   'number': '4U 9XL',
#   'callSign': 'GWI9XL',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AGWK', 'modeS': '3C5EEB', 'model': 'Airbus A319'},
#   'airline': {'name': 'Germanwings', 'iata': '4U', 'icao': 'GWI'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-07-08 06:45Z',
#     'local': '2024-07-08 08:45+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:45Z',
#     'local': '2024-07-08 08:45+02:00'},
#    'runwayTime': {'utc': '2024-07-08 07:03Z',
#     'local': '2024-07-08 09:03+02:00'},
#    'terminal': '1',
#    'checkInDesk': '259-335',
#    'gate': 'A22',
#    'runway': '18',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 07:55Z',
#     'local': '2024-07-08 09:55+02:00'},
#    'revisedTime': {'utc': '2024-07-08 07:50Z',
#     'local': '2024-07-08 09:50+02:00'},
#    'terminal': '1',
#    'gate': 'B06',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 176',
#   'callSign': 'DLH7PK',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIRL', 'modeS': '3C664C', 'model': 'Airbus A321-100'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'EDDM',
#     'iata': 'MUC',
#     'name': 'Munich',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-07-08 06:00Z',
#     'local': '2024-07-08 08:00+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:00Z',
#     'local': '2024-07-08 08:00+02:00'},
#    'runwayTime': {'utc': '2024-07-08 06:16Z',
#     'local': '2024-07-08 08:16+02:00'},
#    'terminal': '2',
#    'runway': '08L',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 07:05Z',
#     'local': '2024-07-08 09:05+02:00'},
#    'revisedTime': {'utc': '2024-07-08 07:01Z',
#     'local': '2024-07-08 09:01+02:00'},
#    'terminal': '1',
#    'gate': 'B20',
#    'baggageBelt': 'B2',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 1930',
#   'callSign': 'DLH2X',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AILX', 'modeS': '3C6598', 'model': 'Airbus A319'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'EDDS',
#     'iata': 'STR',
#     'name': 'Stuttgart',
#     'timeZone': 'Europe/Berlin'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 07:45Z',
#     'local': '2024-07-08 09:45+02:00'},
# ...
#   'aircraft': {'reg': 'OE-IZN', 'modeS': '440CA9', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'LOWW',
#     'iata': 'VIE',
#     'name': 'Vienna',
#     'timeZone': 'Europe/Vienna'},
#    'scheduledTime': {'utc': '2024-07-08 07:55Z',
#     'local': '2024-07-08 09:55+02:00'},
#    'revisedTime': {'utc': '2024-07-08 08:14Z',
#     'local': '2024-07-08 10:14+02:00'},
#    'terminal': '1',
#    'checkInDesk': '151-162',
#    'gate': 'C40',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 09:15Z',
#     'local': '2024-07-08 11:15+02:00'},
#    'revisedTime': {'utc': '2024-07-08 09:05Z',
#     'local': '2024-07-08 11:05+02:00'},
#    'runwayTime': {'utc': '2024-07-08 09:04Z',
#     'local': '2024-07-08 11:04+02:00'},
#    'terminal': '1',
#    'gate': 'A36',
#    'baggageBelt': 'A3',
#    'runway': '25L',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8751',
#   'callSign': 'EWG2NY',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIDO', 'modeS': '3C648F', 'model': 'Airbus A321'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'LSZH',
#     'iata': 'ZRH',
#     'name': 'Zurich',
#     'timeZone': 'Europe/Zurich'},
#    'scheduledTime': {'utc': '2024-07-08 07:50Z',
#     'local': '2024-07-08 09:50+02:00'},
#    'revisedTime': {'utc': '2024-07-08 07:50Z',
#     'local': '2024-07-08 09:50+02:00'},
#    'runwayTime': {'utc': '2024-07-08 08:11Z',
#     'local': '2024-07-08 10:11+02:00'},
#    'checkInDesk': '2(5)',
#    'gate': 'A75',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 09:30Z',
#     'local': '2024-07-08 11:30+02:00'},
#    'revisedTime': {'utc': '2024-07-08 09:12Z',
#     'local': '2024-07-08 11:12+02:00'},
#    'runwayTime': {'utc': '2024-07-08 09:11Z',
#     'local': '2024-07-08 11:11+02:00'},
#    'terminal': '1',
#    'gate': 'A22',
#    'baggageBelt': 'B4',
#    'runway': '25L',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8761',
#   'callSign': 'EWG2BA',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AGWF', 'modeS': '3C5EE6', 'model': 'Airbus A319'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'BIKF',
#     'iata': 'KEF',
#     'name': 'Reykjavik',
#     'timeZone': 'Atlantic/Reykjavik'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 09:19Z',
#     'local': '2024-07-08 11:19+02:00'},
#    'revisedTime': {'utc': '2024-07-08 09:19Z',
#     'local': '2024-07-08 11:19+02:00'},
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'FPY 33G',
#   'callSign': 'FPY33G',
#   'status': 'Approaching',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TF-PLC', 'modeS': '4CC56D', 'model': 'Airbus A321 NEO'},
#   'airline': {'name': 'FPY'}},
#  {'departure': {'airport': {'icao': 'EIDW',
#     'iata': 'DUB',
#     'name': 'Dublin',
#     'timeZone': 'Europe/Dublin'},
#    'scheduledTime': {'utc': '2024-07-08 06:50Z',
#     'local': '2024-07-08 07:50+01:00'},
#    'revisedTime': {'utc': '2024-07-08 06:50Z',
#     'local': '2024-07-08 07:50+01:00'},
#    'runwayTime': {'utc': '2024-07-08 07:33Z',
#     'local': '2024-07-08 08:33+01:00'},
#    'terminal': '1',
#    'checkInDesk': '1205-1319',
#    'gate': '113',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 09:05Z',
#     'local': '2024-07-08 11:05+02:00'},
#    'revisedTime': {'utc': '2024-07-08 09:12Z',
#     'local': '2024-07-08 11:12+02:00'},
#    'runwayTime': {'utc': '2024-07-08 09:12Z',
#     'local': '2024-07-08 11:12+02:00'},
#    'terminal': '2',
#    'gate': 'Z38',
#    'baggageBelt': 'C2',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 3669',
#   'callSign': 'RYR3TF',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-VUH', 'modeS': '4D2347', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'LIRF',
#     'iata': 'FCO',
#     'name': 'Rome',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-07-08 06:55Z',
#     'local': '2024-07-08 08:55+02:00'},
#    'revisedTime': {'utc': '2024-07-08 07:18Z',
#     'local': '2024-07-08 09:18+02:00'},
#    'runwayTime': {'utc': '2024-07-08 07:18Z',
#     'local': '2024-07-08 09:18+02:00'},
#    'terminal': '1',
#    'runway': '25',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 09:05Z',
#     'local': '2024-07-08 11:05+02:00'},
#    'revisedTime': {'utc': '2024-07-08 08:58Z',
#     'local': '2024-07-08 10:58+02:00'},
#    'terminal': '2',
#    'gate': 'Z30',
#    'baggageBelt': 'C3',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 41',
#   'callSign': 'RYR83PC',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-VVA',
#    'modeS': '4D2382',
#    'model': 'Boeing 737 MAX 8'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'EGLL',
#     'iata': 'LHR',
#     'name': 'London',
#     'timeZone': 'Europe/London'},
#    'scheduledTime': {'utc': '2024-07-08 07:55Z',
#     'local': '2024-07-08 08:55+01:00'},
#    'revisedTime': {'utc': '2024-07-08 08:34Z',
#     'local': '2024-07-08 09:34+01:00'},
#    'runwayTime': {'utc': '2024-07-08 08:35Z',
#     'local': '2024-07-08 09:35+01:00'},
#    'terminal': '5',
#    'checkInDesk': 'C',
#    'runway': '27R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 09:45Z',
#     'local': '2024-07-08 11:45+02:00'},
#    'revisedTime': {'utc': '2024-07-08 09:52Z',
#     'local': '2024-07-08 11:52+02:00'},
#    'runwayTime': {'utc': '2024-07-08 09:52Z',
#     'local': '2024-07-08 11:52+02:00'},
#    'terminal': '1',
#    'gate': 'X10',
#    'baggageBelt': 'B1',
#    'runway': '25L',
#    'quality': ['Basic', 'Live']},
#   'number': 'BA 982',
#   'callSign': 'BAW982G',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'G-DBCD', 'modeS': '400B82', 'model': 'Airbus A319'},
#   'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#  {'departure': {'airport': {'icao': 'EHAM',
#     'iata': 'AMS',
#     'name': 'Amsterdam',
#     'timeZone': 'Europe/Amsterdam'},
#    'scheduledTime': {'utc': '2024-07-08 08:15Z',
#     'local': '2024-07-08 10:15+02:00'},
#    'revisedTime': {'utc': '2024-07-08 08:17Z',
#     'local': '2024-07-08 10:17+02:00'},
#    'runwayTime': {'utc': '2024-07-08 08:32Z',
#     'local': '2024-07-08 10:32+02:00'},
#    'terminal': '1',
#    'checkInDesk': '6-8',
#    'gate': 'D74',
#    'runway': '18L',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 09:30Z',
#     'local': '2024-07-08 11:30+02:00'},
#    'revisedTime': {'utc': '2024-07-08 09:23Z',
#     'local': '2024-07-08 11:23+02:00'},
#    'terminal': '1',
#    'gate': 'B07',
#    'baggageBelt': 'B2',
#    'quality': ['Basic', 'Live']},
#   'number': 'KL 1775',
#   'callSign': 'KLM1775',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'PH-BXD',
#    'modeS': '484133',
#    'model': 'Boeing 737-800 (winglets)'},
#   'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#  {'departure': {'airport': {'icao': 'BIKF',
#     'iata': 'KEF',
#     'name': 'Reykjavik',
#     'timeZone': 'Atlantic/Reykjavik'},
#    'scheduledTime': {'utc': '2024-07-08 06:00Z',
#     'local': '2024-07-08 06:00+00:00'},
#    'revisedTime': {'utc': '2024-07-08 05:53Z',
#     'local': '2024-07-08 05:53+00:00'},
#    'runwayTime': {'utc': '2024-07-08 06:07Z',
#     'local': '2024-07-08 06:07+00:00'},
#    'gate': 'C35',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 09:30Z',
#     'local': '2024-07-08 11:30+02:00'},
#    'revisedTime': {'utc': '2024-07-08 09:20Z',
#     'local': '2024-07-08 11:20+02:00'},
#    'terminal': '2',
#    'gate': 'Z36',
#    'baggageBelt': 'C1',
#    'quality': ['Basic', 'Live']},
#   'number': 'OG 700',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TF-PLC', 'modeS': '4CC56D', 'model': 'Airbus A321 NEO'},
#   'airline': {'name': 'Ghodawat Enterprises', 'iata': 'OG', 'icao': 'SDG'}},
#  {'departure': {'airport': {'icao': 'LEPA',
#     'iata': 'PMI',
#     'name': 'Palma De Mallorca',
#     'timeZone': 'Europe/Madrid'},
#    'scheduledTime': {'utc': '2024-07-08 06:45Z',
#     'local': '2024-07-08 08:45+02:00'},
#    'revisedTime': {'utc': '2024-07-08 06:54Z',
#     'local': '2024-07-08 08:54+02:00'},
#    'runwayTime': {'utc': '2024-07-08 07:11Z',
#     'local': '2024-07-08 09:11+02:00'},
#    'terminal': 'N',
#    'checkInDesk': '019-024',
#    'gate': 'C40',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 09:45Z',
#     'local': '2024-07-08 11:45+02:00'},
#    'revisedTime': {'utc': '2024-07-08 09:21Z',
#     'local': '2024-07-08 11:21+02:00'},
#    'terminal': '1',
#    'gate': 'A35',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'SR 2413',
#   'callSign': 'SDR21YY',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-ASMR', 'modeS': '3C0936', 'model': 'Airbus A320'},
#   'airline': {'name': 'SundAir', 'iata': 'SR', 'icao': 'SDR'}},
#  {'departure': {'airport': {'icao': 'LTFM',
#     'iata': 'IST',
#     'name': 'Istanbul',
#     'timeZone': 'Europe/Istanbul'},
#    'scheduledTime': {'utc': '2024-07-08 07:00Z',
#     'local': '2024-07-08 10:00+03:00'},
#    'revisedTime': {'utc': '2024-07-08 07:00Z',
#     'local': '2024-07-08 10:00+03:00'},
#    'runwayTime': {'utc': '2024-07-08 07:23Z',
#     'local': '2024-07-08 10:23+03:00'},
#    'checkInDesk': 'E-F',
#    'gate': 'F3A',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 09:45Z',
#     'local': '2024-07-08 11:45+02:00'},
#    'revisedTime': {'utc': '2024-07-08 09:37Z',
#     'local': '2024-07-08 11:37+02:00'},
#    'terminal': '1',
#    'gate': 'X01',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'TK 1729',
#   'callSign': 'THY5HW',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-JRT', 'modeS': '4BAA54', 'model': 'Airbus A321'},
#   'airline': {'name': 'Turkish', 'iata': 'TK', 'icao': 'THY'}},
#  {'departure': {'airport': {'icao': 'LGTS',
#     'iata': 'SKG',
#     'name': 'Thessaloniki',
#     'timeZone': 'Europe/Athens'},
#    'scheduledTime': {'utc': '2024-07-08 07:10Z',
#     'local': '2024-07-08 10:10+03:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 09:40Z',
#     'local': '2024-07-08 11:40+02:00'},
#    'revisedTime': {'utc': '2024-07-08 09:27Z',
#     'local': '2024-07-08 11:27+02:00'},
#    'terminal': '1',
#    'gate': 'A33',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5028',
#   'callSign': 'EJU68AP',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IWW', 'modeS': '440B1E', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LSGG',
#     'iata': 'GVA',
#     'name': 'Geneva',
#     'timeZone': 'Europe/Zurich'},
#    'scheduledTime': {'utc': '2024-07-08 07:25Z',
#     'local': '2024-07-08 09:25+02:00'},
#    'revisedTime': {'utc': '2024-07-08 07:25Z',
#     'local': '2024-07-08 09:25+02:00'},
#    'runwayTime': {'utc': '2024-07-08 07:36Z',
#     'local': '2024-07-08 09:36+02:00'},
#    'terminal': '1',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 09:10Z',
#     'local': '2024-07-08 11:10+02:00'},
#    'revisedTime': {'utc': '2024-07-08 08:51Z',
#     'local': '2024-07-08 10:51+02:00'},
#    'terminal': '1',
#    'gate': 'S02',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5182',
#   'callSign': 'EJU59XM',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IZN', 'modeS': '440CA9', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LTFJ',
#     'iata': 'SAW',
#     'name': 'Istanbul',
#     'timeZone': 'Europe/Istanbul'},
#    'scheduledTime': {'utc': '2024-07-08 06:25Z',
#     'local': '2024-07-08 09:25+03:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 09:20Z',
#     'local': '2024-07-08 11:20+02:00'},
#    'revisedTime': {'utc': '2024-07-08 09:46Z',
#     'local': '2024-07-08 11:46+02:00'},
#    'terminal': '1',
#    'gate': 'N02',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'VF 57',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-JFF', 'modeS': '4BA8C6', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ajet', 'iata': 'VF', 'icao': 'VLU'}},
#  {'departure': {'airport': {'icao': 'LTAI',
#     'iata': 'AYT',
#     'name': 'Antalya',
#     'timeZone': 'Europe/Istanbul'},
#    'scheduledTime': {'utc': '2024-07-08 06:00Z',
#     'local': '2024-07-08 09:00+03:00'},
#    'revisedTime': {'utc': '2024-07-08 06:00Z',
#     'local': '2024-07-08 09:00+03:00'},
#    'terminal': '1',
#    'checkInDesk': '126-128',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 09:35Z',
#     'local': '2024-07-08 11:35+02:00'},
#    'revisedTime': {'utc': '2024-07-08 09:28Z',
#     'local': '2024-07-08 11:28+02:00'},
#    'terminal': '1',
#    'gate': 'X07',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'XQ 160',
#   'callSign': 'SXS2SR',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-SMK',
#    'modeS': '4BCDAB',
#    'model': 'Boeing 737 MAX 8'},
#   'airline': {'name': 'Sun Express', 'iata': 'XQ', 'icao': 'SXS'}},
#  {'departure': {'airport': {'icao': 'LIPE',
#     'iata': 'BLQ',
#     'name': 'Bologna',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-07-08 08:25Z',
#     'local': '2024-07-08 10:25+02:00'},
#    'revisedTime': {'utc': '2024-07-08 08:29Z',
#     'local': '2024-07-08 10:29+02:00'},
#    'runwayTime': {'utc': '2024-07-08 08:29Z',
#     'local': '2024-07-08 10:29+02:00'},
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 10:10Z',
#     'local': '2024-07-08 12:10+02:00'},
#    'revisedTime': {'utc': '2024-07-08 09:48Z',
#     'local': '2024-07-08 11:48+02:00'},
#    'runwayTime': {'utc': '2024-07-08 09:48Z',
#     'local': '2024-07-08 11:48+02:00'},
#    'terminal': '2',
#    'gate': 'Z34',
#    'baggageBelt': 'C2',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 137',
#   'callSign': 'RYR8JN',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-QCC', 'modeS': '4D2228', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'EDDM',
#     'iata': 'MUC',
#     'name': 'Munich',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-07-08 09:00Z',
#     'local': '2024-07-08 11:00+02:00'},
#    'revisedTime': {'utc': '2024-07-08 09:00Z',
#     'local': '2024-07-08 11:00+02:00'},
#    'runwayTime': {'utc': '2024-07-08 09:08Z',
#     'local': '2024-07-08 11:08+02:00'},
#    'terminal': '2',
#    'runway': '08L',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-07-08 10:05Z',
#     'local': '2024-07-08 12:05+02:00'},
#    'revisedTime': {'utc': '2024-07-08 09:54Z',
#     'local': '2024-07-08 11:54+02:00'},
#    'runwayTime': {'utc': '2024-07-08 09:53Z',
#     'local': '2024-07-08 11:53+02:00'},
#    'terminal': '1',
#    'gate': 'B17',
#    'baggageBelt': 'B4',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 1926',
#   'callSign': 'DLH1926',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AISX', 'modeS': '3C6678', 'model': 'Airbus A321'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}}]

# %%
flights_json["arrivals"][0]
# Out:
# {'departure': {'airport': {'icao': 'EDDK',
#    'iata': 'CGN',
#    'name': 'Cologne',
#    'timeZone': 'Europe/Berlin'},
#   'scheduledTime': {'utc': '2024-07-08 02:46Z',
#    'local': '2024-07-08 04:46+02:00'},
#   'revisedTime': {'utc': '2024-07-08 02:46Z',
#    'local': '2024-07-08 04:46+02:00'},
#   'runwayTime': {'utc': '2024-07-08 02:46Z',
#    'local': '2024-07-08 04:46+02:00'},
#   'runway': '06',
#   'quality': ['Basic', 'Live']},
#  'arrival': {'scheduledTime': {'utc': '2024-07-08 03:25Z',
#    'local': '2024-07-08 05:25+02:00'},
#   'revisedTime': {'utc': '2024-07-08 03:25Z',
#    'local': '2024-07-08 05:25+02:00'},
#   'quality': ['Basic', 'Live']},
#  'number': 'DJ 6228',
#  'callSign': 'SRR6228',
#  'status': 'Approaching',
#  'codeshareStatus': 'IsOperator',
#  'isCargo': False,
#  'aircraft': {'reg': 'OY-SRM', 'modeS': '45CE4D', 'model': 'Boeing 767'},
#  'airline': {'name': 'Star Air A/S', 'iata': 'DJ', 'icao': 'SRR'}}

# %%
flights_json["arrivals"][0].keys()
# Out:
# dict_keys(['departure', 'arrival', 'number', 'callSign', 'status', 'codeshareStatus', 'isCargo', 'aircraft', 'airline'])

# %% [markdown]
# Useful Info:
# * Departure airport icao
# * scheduled arrival time, local
# * flight number

# %% [markdown]
# ## Creating the DataFrame

# %% [markdown]
# ### Using Loops

# %%
flight_items = [] # Empty list

for item in flights_json["arrivals"]: # Referring to arrivals dict in flights_json
    flight_item = {
        "arrival airport_icao" : icao, 
        "departure_airport_icao": item["departure"]["airport"].get("icao", None),  #item["Key"]["Value"].get("1st element")
        "scheduled_arrival_time" : item["arrival"]["scheduledTime"].get("local", None),
        "arrival_terminal" : item['arrival'].get('terminal', None),
        "flight_number" : item.get("number", None)
    } # Defining the elements in for loop completed
    
    flight_items.append(flight_item) # The one to which we append comes first followed by one getting appended
    
flights_df = pd.DataFrame(flight_items)

flights_df.head()
# Out:
#   arrival airport_icao departure_airport_icao  scheduled_arrival_time  \
# 0                 EDDB                   EDDK  2024-07-08 05:25+02:00
# 1                 EDDB                   UGTB  2024-07-08 05:40+02:00
# 2                 EDDB                   ZBAA  2024-07-08 06:45+02:00
# 3                 EDDB                   EVRA  2024-07-08 07:40+02:00
# 4                 EDDB                   EVRA  2024-07-08 07:40+02:00
#
#   arrival_terminal flight_number
# 0             None       DJ 6228
# 1                1       EW 8993
# 2                1        HU 489
# 3                1        BT 211
# 4                1       DL 7313

# %% [markdown]
# We can see in the above result under arrival_time column, there is an offset "+2:00".
# We need to get rid of it as it will complicate our analysis and will not provide accurate results.

# %%
flights_df["scheduled_arrival_time"] = flights_df["scheduled_arrival_time"].str[:-6] # Removing last 6 characters from the string
flights_df.head()
# Out:
#   arrival airport_icao departure_airport_icao scheduled_arrival_time  \
# 0                 EDDB                   EDDK       2024-07-08 05:25
# 1                 EDDB                   UGTB       2024-07-08 05:40
# 2                 EDDB                   ZBAA       2024-07-08 06:45
# 3                 EDDB                   EVRA       2024-07-08 07:40
# 4                 EDDB                   EVRA       2024-07-08 07:40
#
#   arrival_terminal flight_number
# 0             None       DJ 6228
# 1                1       EW 8993
# 2                1        HU 489
# 3                1        BT 211
# 4                1       DL 7313

# %% [markdown]
# ## Creating a function for multiple cities

# %%
import pandas as pd
from datetime import datetime, timedelta
import requests
from pytz import timezone

def get_flight_data(icao_list):
  api_key = #"Your Key"

  berlin_timezone = timezone('Europe/Berlin')
  today = datetime.now(berlin_timezone).date()
  tomorrow = (today + timedelta(days=1))

  flight_items = []

  for icao in icao_list:
    # the api can only make 12 hour calls, therefore, two 12 hour calls make a full day
    # using the nested lists below we can make a morning call and extract the data
    # then make an afternoon call and extract the data
    times = [["00:00","11:59"],
             ["12:00","23:59"]]

    for time in times:
      url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/{tomorrow}T{time[0]}/{tomorrow}T{time[1]}"

      querystring = {"withLeg":"true",
                    "direction":"Arrival",
                    "withCancelled":"false",
                    "withCodeshared":"true",
                    "withCargo":"false",
                    "withPrivate":"false"}

      headers = {
          'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
          'x-rapidapi-key': api_key
          }

      response = requests.request("GET",
                                  url,
                                  headers = headers,
                                  params = querystring)

      flights_json = response.json()

      retrieval_time = datetime.now(berlin_timezone).strftime("%Y-%m-%d %H:%M:%S")

      for item in flights_json["arrivals"]:
        flight_item = {
            "arrival_airport_icao": icao,
            "departure_airport_icao": item["departure"]["airport"].get("icao", None),
            "scheduled_arrival_time": item["arrival"]["scheduledTime"].get("local", None),
            'arrival_terminal': item['arrival'].get('terminal', None),
            "flight_number": item.get("number", None),
            "data_retrieved_at": retrieval_time
        }

        flight_items.append(flight_item)

  flights_df = pd.DataFrame(flight_items)
  flights_df["scheduled_arrival_time"] = flights_df["scheduled_arrival_time"].str[:-6]
  flights_df["scheduled_arrival_time"] = pd.to_datetime(flights_df["scheduled_arrival_time"])
  flights_df["data_retrieved_at"] = pd.to_datetime(flights_df["data_retrieved_at"])

  return flights_df

# %%
icao_list = ["EDDB", "EDDH", "EDDM"]

get_flight_data(icao_list)
# Out:
#     arrival_airport_icao departure_airport_icao scheduled_arrival_time  \
# 0                   EDDB                   BIKF    2024-07-09 06:15:00
# 1                   EDDB                   LTCC    2024-07-09 06:45:00
# 2                   EDDB                   LTBJ    2024-07-09 06:30:00
# 3                   EDDB                   None    2024-07-09 07:20:00
# 4                   EDDB                   EVRA    2024-07-09 07:40:00
# ..                   ...                    ...                    ...
# 922                 EDDM                   LEPA    2024-07-09 23:25:00
# 923                 EDDM                   EGLL    2024-07-09 23:15:00
# 924                 EDDM                   LPPT    2024-07-09 23:30:00
# 925                 EDDM                   LPMA    2024-07-09 23:15:00
# 926                 EDDM                   HEGN    2024-07-09 23:25:00
#
#     arrival_terminal flight_number   data_retrieved_at
# 0                  1        FI 518 2024-07-08 12:45:35
# 1                  1       XQ 1700 2024-07-08 12:45:35
# 2                  1        XQ 966 2024-07-08 12:45:35
# 3                  1        5F 611 2024-07-08 12:45:35
# 4                  1       A3 3219 2024-07-08 12:45:35
# ..               ...           ...                 ...
# 922                1       DE 1131 2024-07-08 12:45:36
# 923                2       LH 2481 2024-07-08 12:45:36
# 924                2        TP 556 2024-07-08 12:45:36
# 925                1       X3 2847 2024-07-08 12:45:36
# 926                1       X3 6683 2024-07-08 12:45:36
#
# [927 rows x 6 columns]

# %% [markdown]
# Using normalize method

# %%
def tomorrows_flight_arrivals(icao_list):

    api_key = "14a44098c8mshe4536a007985112p1e3b4bjsn8fd805eb6bd4"

    berlin_timezone = timezone('Europe/Berlin')
    today = datetime.now(berlin_timezone).date()
    tomorrow = (today + timedelta(days=1))

    list_for_arrivals_df = []

    for icao in icao_list:

        times = [["00:00","11:59"],["12:00","23:59"]]

        for time in times:
            url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/{tomorrow}T{time[0]}/{tomorrow}T{time[1]}"

            querystring = {"direction":"Arrival","withCancelled":"false"}

            headers = {
                "X-RapidAPI-Key": #"Your Key",
                "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
                }

            response = requests.request("GET", url, headers=headers, params=querystring)
            flights_resp = response.json()

            arrivals_df = pd.json_normalize(flights_resp["arrivals"])[["number", "airline.name", "movement.scheduledTime.local", "movement.terminal", "movement.airport.name", "movement.airport.icao"]]
            arrivals_df = arrivals_df.rename(columns={"number": "flight_number", "airline.name": "airline", "movement.scheduledTime.local": "arrival_time", "movement.terminal": "arrival_terminal", "movement.airport.name": "departure_city", "movement.airport.icao": "departure_airport_icao"})
            arrivals_df["arrival_airport_icao"] = icao
            arrivals_df["data_retrieved_on"] = datetime.now().date()
            arrivals_df = arrivals_df[["arrival_airport_icao", "flight_number", "airline", "arrival_time", "arrival_terminal", "departure_city", "departure_airport_icao", "data_retrieved_on"]]

            # fixing arrival_time
            arrivals_df["arrival_time"] = arrivals_df["arrival_time"].str.split("+").str[0]

            list_for_arrivals_df.append(arrivals_df)

    return pd.concat(list_for_arrivals_df, ignore_index=True)

# %%
icao_list = ["EDDB", "EDDH", "EDDM"]

tomorrows_flight_arrivals(icao_list)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\USER_N~1\AppData\Local\Temp/ipykernel_18632/3093067684.py in <module>
#       1 icao_list = ["EDDB", "EDDH", "EDDM"]
#       2
# ----> 3 tomorrows_flight_arrivals(icao_list)
#
# C:\Users\USER_N~1\AppData\Local\Temp/ipykernel_18632/3524012470.py in tomorrows_flight_arrivals(icao_list)
#      26             flights_resp = response.json()
#      27
# ---> 28             arrivals_df = pd.json_normalize(flights_resp["arrivals"])[["number", "airline.name", "movement.scheduledTime.local", "movement.terminal", "movement.airport.name", "movement.airport.icao"]]
#      29             arrivals_df = arrivals_df.rename(columns={"number": "flight_number", "airline.name": "airline", "movement.scheduledTime.local": "arrival_time", "movement.terminal": "arrival_terminal", "movement.airport.name": "departure_city", "movement.airport.icao": "departure_airport_icao"})
#      30             arrivals_df["arrival_airport_icao"] = icao
#
# KeyError: 'arrivals'
