# %%
## !pip install sqlalchemy
# !pip install pymysql
# Out:
# Requirement already satisfied: pymysql in c:\users\user_name\anaconda3\lib\site-packages (1.1.1)

# %% [markdown]
# Installing the essential libraries

# %%
#Installing all the essential libraries first
import pandas as pd
import requests
from bs4 import BeautifulSoup
# !pip install lat_lon_parser
from datetime import datetime
# Out:
# Requirement already satisfied: lat_lon_parser in c:\users\user_name\anaconda3\lib\site-packages (1.3.0)

# %% [markdown]
# # Calling the cities function

# %% [markdown]
# This function consists the cities name, lat/long and population data

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from lat_lon_parser import parse    # for decimal coordinates


def cities_dataframe(cities):

  city_data = []

  for city in cities:
    url = f"https://www.wikipedia.org/wiki/{city}"
    response = requests.get(url)
    city_soup = BeautifulSoup(response.content, 'html.parser')

    # extract the relevant information
    city_population = city_soup.find(string="Population").find_next("td").get_text()
    city_population_clean = int(city_population.replace(",", ""))
    today = datetime.today().strftime("%d.%m.%Y")  
    city_latitude = city_soup.find(class_="latitude").get_text()
    city_longitude = city_soup.find(class_="longitude").get_text()
    country = city_soup.find(class_="infobox-data").get_text()

    # Append the information to the empty lists
    city_data.append({"City": city,
                    "Country": country,
                    "Latitude": parse(city_latitude), # latitude in decimal format
                    "Longitude": parse(city_longitude), # longitude in decimal format
                    "Population": city_population_clean,
                    "Timestamp": today
                    })

  return pd.DataFrame(city_data)

# %% [markdown]
# Calling the function

# %%
# call the function
list_of_cities = ["Berlin", "Hamburg", "Munich"]

cities_df = cities_dataframe(list_of_cities)
cities_df
# Out:
#       City  Country  Latitude  Longitude  Population   Timestamp
# 0   Berlin  Germany   52.5200     13.405     3878100  08.07.2024
# 1  Hamburg  Germany   53.5500     10.000     1964021  08.07.2024
# 2   Munich  Germany   48.1375     11.575     1512491  08.07.2024

# %% [markdown]
# Dropping the duplicates and keeping only unique cities with countries (in our case we have only unique cities)

# %%
Cities_df = cities_df.drop_duplicates(subset='City')[['City', 'Country']].reset_index(drop=True)
Cities_df
# Out:
#       City  Country
# 0   Berlin  Germany
# 1  Hamburg  Germany
# 2   Munich  Germany

# %% [markdown]
# ## Establishing the SQL connection

# %%
schema = #"schema name" # Name of Schema changes
host = #"host id"
user = #"root"
password = #"your password" # Password changes
port = #port number

connection_string = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

# %% [markdown]
# ## Pushing the data to city table in SQL

# %%
Cities_df.to_sql('city',
                  if_exists='append',
                  con=connection_string,
                  index=False)

# %% [markdown]
# ## Retrieving the data from SQL table (Since we get the City_id column now)

# %%
city_from_sql = pd.read_sql("city", con = connection_string)
city_from_sql
# Out:
#    City_id     City  Country
# 0        1   Berlin  Germany
# 1        2  Hamburg  Germany
# 2        3   Munich  Germany

# %% [markdown]
# creating copy of the sql table to keep original DF untouched

# %%
city_from_sql1 = city_from_sql.copy()
city_from_sql1
# Out:
#    City_id     City  Country
# 0        1   Berlin  Germany
# 1        2  Hamburg  Germany
# 2        3   Munich  Germany

# %% [markdown]
# Merging the sql cities table with the initial table to get the City_id in the intial table

# %%
cities_df = cities_df.merge(city_from_sql, on = "City", how = "left")

cities_df
# Out:
#       City Country_x  Latitude  Longitude  Population   Timestamp  City_id  \
# 0   Berlin   Germany   52.5200     13.405     3878100  08.07.2024        1
# 1  Hamburg   Germany   53.5500     10.000     1964021  08.07.2024        2
# 2   Munich   Germany   48.1375     11.575     1512491  08.07.2024        3
#
#   Country_y
# 0   Germany
# 1   Germany
# 2   Germany

# %% [markdown]
# Dropping unnecessary columns

# %%
cities_df = cities_df.drop(columns = ["City", "Country_x", "Country_y"])

cities_df
# Out:
#    Latitude  Longitude  Population   Timestamp  City_id
# 0   52.5200     13.405     3878100  08.07.2024        1
# 1   53.5500     10.000     1964021  08.07.2024        2
# 2   48.1375     11.575     1512491  08.07.2024        3

# %% [markdown]
# Converting the Timestamp column data-type to date type

# %%
cities_df['Timestamp'] = pd.to_datetime(cities_df['Timestamp'])
cities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Latitude    3 non-null      float64
#  1   Longitude   3 non-null      float64
#  2   Population  3 non-null      int64
#  3   Timestamp   3 non-null      datetime64[ns]
#  4   City_id     3 non-null      int64
# dtypes: datetime64[ns](1), float64(2), int64(2)
# memory usage: 144.0 bytes

# %%
cities_df.rename(columns={"Timestamp": "Timestamp_"}, inplace=True)

cities_df
# Out:
#    Latitude  Longitude  Population Timestamp_  City_id
# 0   52.5200     13.405     3878100 2024-08-07        1
# 1   53.5500     10.000     1964021 2024-08-07        2
# 2   48.1375     11.575     1512491 2024-08-07        3

# %%
cities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Latitude    3 non-null      float64
#  1   Longitude   3 non-null      float64
#  2   Population  3 non-null      int64
#  3   Timestamp_  3 non-null      datetime64[ns]
#  4   City_id     3 non-null      int64
# dtypes: datetime64[ns](1), float64(2), int64(2)
# memory usage: 144.0 bytes

# %% [markdown]
# ## Pushing the data to city_info table in SQL

# %%
cities_df.to_sql('city_info',
                if_exists='append',
                con=connection_string,
                index=False)

# %% [markdown]
# ## Retrieving the data from SQL table (just to review)

# %%
city_info_from_sql = pd.read_sql("city_info", con = connection_string)
city_info_from_sql
# Out:
#    Latitude  Longitude  Population Timestamp_  City_id
# 0   52.5200     13.405     3878100 2024-08-07        1
# 1   53.5500     10.000     1964021 2024-08-07        2
# 2   48.1375     11.575     1512491 2024-08-07        3

# %%
city_info_from_sql.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Latitude    3 non-null      float64
#  1   Longitude   3 non-null      float64
#  2   Population  3 non-null      int64
#  3   Timestamp_  3 non-null      datetime64[ns]
#  4   City_id     3 non-null      int64
# dtypes: datetime64[ns](1), float64(2), int64(2)
# memory usage: 248.0 bytes

# %% [markdown]
# # Calling the weather (for multiple cities) function

# %%
def fetch_weather_data(cities): # Defining the function with parameter cities
    # Ensuring the timezone is local
    berlin_timezone = timezone("Europe/Berlin")
    API_key = #"Your_API_Key"
    weather_items = [] # Created an empty list which will be appended with the output from the for loop
    
    for city in cities:
        country = "DE"
        
        # Geocoder api to get the latitude and longitude
        geo_url = (f"http://api.openweathermap.org/geo/1.0/direct?q={city},{country}&limit=5&appid={API_key}")
        geo_response = requests.get(geo_url)
        geo_json = geo_response.json()
        latitude = geo_json[0]["lat"]
        longitude = geo_json[0]["lon"]
        
        # Calling the weather api
        weather_url = (f"https://api.openweathermap.org/data/2.5/forecast?lat={latitude}&lon={longitude}&appid={API_key}&units=metric")
        weather_response = requests.get(weather_url)
        w_json = weather_response.json()
        
        # Added the time retrieved so we know when the forecast was made
        retrieval_time = datetime.now(berlin_timezone).strftime("%Y-%m-%d %H:%M:%S")

        for item in w_json["list"]:
            weather_item = {
            # Added the city name, so the information is clear when looking at multiple cities
                "city": city,
                "forecast_time": item.get("dt_txt", None),
                "temperature": item["main"].get("temp", None),
                "forecast": item["weather"][0].get("main", None),
                "forecast desc.": item["weather"][0].get("description", None),
                "rain_in_last_3h": item.get("rain", {}).get("3h", 0),
                "wind_speed": item["wind"].get("speed", None),
                "data_retrieved_at": retrieval_time
            }

            weather_items.append(weather_item)

    weather_df = pd.DataFrame(weather_items)

    return weather_df

# %% [markdown]
# Importing essential libraries

# %%
from datetime import datetime
from pytz import timezone

# %% [markdown]
# Calling the function

# %%
fetch_weather_data(["Berlin", "Hamburg", "Munich"])
# Out:
#        city        forecast_time  temperature forecast   forecast desc.  \
# 0    Berlin  2024-07-08 12:00:00        25.44    Clear        clear sky
# 1    Berlin  2024-07-08 15:00:00        25.04   Clouds    broken clouds
# 2    Berlin  2024-07-08 18:00:00        23.66   Clouds  overcast clouds
# 3    Berlin  2024-07-08 21:00:00        20.44   Clouds  overcast clouds
# 4    Berlin  2024-07-09 00:00:00        18.36   Clouds  overcast clouds
# ..      ...                  ...          ...      ...              ...
# 115  Munich  2024-07-12 21:00:00        16.52     Rain       light rain
# 116  Munich  2024-07-13 00:00:00        16.85   Clouds  overcast clouds
# 117  Munich  2024-07-13 03:00:00        16.77     Rain       light rain
# 118  Munich  2024-07-13 06:00:00        16.68     Rain       light rain
# 119  Munich  2024-07-13 09:00:00        17.63     Rain       light rain
#
#      rain_in_last_3h  wind_speed    data_retrieved_at
# 0               0.00        3.55  2024-07-08 11:59:40
# 1               0.00        3.85  2024-07-08 11:59:40
# 2               0.00        2.49  2024-07-08 11:59:40
# 3               0.00        2.28  2024-07-08 11:59:40
# 4               0.00        2.07  2024-07-08 11:59:40
# ..               ...         ...                  ...
# 115             0.32        2.54  2024-07-08 11:59:41
# 116             0.00        2.22  2024-07-08 11:59:41
# 117             0.36        2.10  2024-07-08 11:59:41
# 118             2.40        1.99  2024-07-08 11:59:41
# 119             0.45        2.11  2024-07-08 11:59:41
#
# [120 rows x 8 columns]

# %% [markdown]
# Converting to a Dataframe (DF)

# %%
weather_info = fetch_weather_data(["Berlin", "Hamburg", "Munich"])
weatherinfo_df = pd.DataFrame(weather_info)
weatherinfo_df
# Out:
#        city        forecast_time  temperature forecast   forecast desc.  \
# 0    Berlin  2024-07-08 12:00:00        25.44    Clear        clear sky
# 1    Berlin  2024-07-08 15:00:00        25.04   Clouds    broken clouds
# 2    Berlin  2024-07-08 18:00:00        23.66   Clouds  overcast clouds
# 3    Berlin  2024-07-08 21:00:00        20.44   Clouds  overcast clouds
# 4    Berlin  2024-07-09 00:00:00        18.36   Clouds  overcast clouds
# ..      ...                  ...          ...      ...              ...
# 115  Munich  2024-07-12 21:00:00        16.52     Rain       light rain
# 116  Munich  2024-07-13 00:00:00        16.85   Clouds  overcast clouds
# 117  Munich  2024-07-13 03:00:00        16.77     Rain       light rain
# 118  Munich  2024-07-13 06:00:00        16.68     Rain       light rain
# 119  Munich  2024-07-13 09:00:00        17.63     Rain       light rain
#
#      rain_in_last_3h  wind_speed    data_retrieved_at
# 0               0.00        3.55  2024-07-08 11:59:52
# 1               0.00        3.85  2024-07-08 11:59:52
# 2               0.00        2.49  2024-07-08 11:59:52
# 3               0.00        2.28  2024-07-08 11:59:52
# 4               0.00        2.07  2024-07-08 11:59:52
# ..               ...         ...                  ...
# 115             0.32        2.54  2024-07-08 11:59:52
# 116             0.00        2.22  2024-07-08 11:59:52
# 117             0.36        2.10  2024-07-08 11:59:52
# 118             2.40        1.99  2024-07-08 11:59:52
# 119             0.45        2.11  2024-07-08 11:59:52
#
# [120 rows x 8 columns]

# %% [markdown]
# Merging the weather and city table

# %%
weatherinfo_merged = weatherinfo_df.merge(city_from_sql, left_on = "city", right_on = "City", how = "right")

weatherinfo_merged
# Out:
#        city        forecast_time  temperature forecast   forecast desc.  \
# 0    Berlin  2024-07-08 12:00:00        25.44    Clear        clear sky
# 1    Berlin  2024-07-08 15:00:00        25.04   Clouds    broken clouds
# 2    Berlin  2024-07-08 18:00:00        23.66   Clouds  overcast clouds
# 3    Berlin  2024-07-08 21:00:00        20.44   Clouds  overcast clouds
# 4    Berlin  2024-07-09 00:00:00        18.36   Clouds  overcast clouds
# ..      ...                  ...          ...      ...              ...
# 115  Munich  2024-07-12 21:00:00        16.52     Rain       light rain
# 116  Munich  2024-07-13 00:00:00        16.85   Clouds  overcast clouds
# 117  Munich  2024-07-13 03:00:00        16.77     Rain       light rain
# 118  Munich  2024-07-13 06:00:00        16.68     Rain       light rain
# 119  Munich  2024-07-13 09:00:00        17.63     Rain       light rain
#
#      rain_in_last_3h  wind_speed    data_retrieved_at  City_id    City  \
# 0               0.00        3.55  2024-07-08 11:59:52        1  Berlin
# 1               0.00        3.85  2024-07-08 11:59:52        1  Berlin
# 2               0.00        2.49  2024-07-08 11:59:52        1  Berlin
# 3               0.00        2.28  2024-07-08 11:59:52        1  Berlin
# 4               0.00        2.07  2024-07-08 11:59:52        1  Berlin
# ..               ...         ...                  ...      ...     ...
# 115             0.32        2.54  2024-07-08 11:59:52        3  Munich
# 116             0.00        2.22  2024-07-08 11:59:52        3  Munich
# 117             0.36        2.10  2024-07-08 11:59:52        3  Munich
# 118             2.40        1.99  2024-07-08 11:59:52        3  Munich
# 119             0.45        2.11  2024-07-08 11:59:52        3  Munich
#
#      Country
# 0    Germany
# 1    Germany
# 2    Germany
# 3    Germany
# 4    Germany
# ..       ...
# 115  Germany
# 116  Germany
# 117  Germany
# 118  Germany
# 119  Germany
#
# [120 rows x 11 columns]

# %%
weatherinfo_merged1 = weatherinfo_merged.copy()
weatherinfo_merged1 # Created a copy to keep the original untouched
# Out:
#        city        forecast_time  temperature forecast   forecast desc.  \
# 0    Berlin  2024-07-08 12:00:00        25.44    Clear        clear sky
# 1    Berlin  2024-07-08 15:00:00        25.04   Clouds    broken clouds
# 2    Berlin  2024-07-08 18:00:00        23.66   Clouds  overcast clouds
# 3    Berlin  2024-07-08 21:00:00        20.44   Clouds  overcast clouds
# 4    Berlin  2024-07-09 00:00:00        18.36   Clouds  overcast clouds
# ..      ...                  ...          ...      ...              ...
# 115  Munich  2024-07-12 21:00:00        16.52     Rain       light rain
# 116  Munich  2024-07-13 00:00:00        16.85   Clouds  overcast clouds
# 117  Munich  2024-07-13 03:00:00        16.77     Rain       light rain
# 118  Munich  2024-07-13 06:00:00        16.68     Rain       light rain
# 119  Munich  2024-07-13 09:00:00        17.63     Rain       light rain
#
#      rain_in_last_3h  wind_speed    data_retrieved_at  City_id    City  \
# 0               0.00        3.55  2024-07-08 11:59:52        1  Berlin
# 1               0.00        3.85  2024-07-08 11:59:52        1  Berlin
# 2               0.00        2.49  2024-07-08 11:59:52        1  Berlin
# 3               0.00        2.28  2024-07-08 11:59:52        1  Berlin
# 4               0.00        2.07  2024-07-08 11:59:52        1  Berlin
# ..               ...         ...                  ...      ...     ...
# 115             0.32        2.54  2024-07-08 11:59:52        3  Munich
# 116             0.00        2.22  2024-07-08 11:59:52        3  Munich
# 117             0.36        2.10  2024-07-08 11:59:52        3  Munich
# 118             2.40        1.99  2024-07-08 11:59:52        3  Munich
# 119             0.45        2.11  2024-07-08 11:59:52        3  Munich
#
#      Country
# 0    Germany
# 1    Germany
# 2    Germany
# 3    Germany
# 4    Germany
# ..       ...
# 115  Germany
# 116  Germany
# 117  Germany
# 118  Germany
# 119  Germany
#
# [120 rows x 11 columns]

# %% [markdown]
# Dropping unnecessary columns

# %%
weatherinfo_merged1 = weatherinfo_merged1.drop(columns = "city")
weatherinfo_merged1
# Out:
#            forecast_time  temperature forecast   forecast desc.  \
# 0    2024-07-08 12:00:00        25.44    Clear        clear sky
# 1    2024-07-08 15:00:00        25.04   Clouds    broken clouds
# 2    2024-07-08 18:00:00        23.66   Clouds  overcast clouds
# 3    2024-07-08 21:00:00        20.44   Clouds  overcast clouds
# 4    2024-07-09 00:00:00        18.36   Clouds  overcast clouds
# ..                   ...          ...      ...              ...
# 115  2024-07-12 21:00:00        16.52     Rain       light rain
# 116  2024-07-13 00:00:00        16.85   Clouds  overcast clouds
# 117  2024-07-13 03:00:00        16.77     Rain       light rain
# 118  2024-07-13 06:00:00        16.68     Rain       light rain
# 119  2024-07-13 09:00:00        17.63     Rain       light rain
#
#      rain_in_last_3h  wind_speed    data_retrieved_at  City_id    City  \
# 0               0.00        3.55  2024-07-08 11:59:52        1  Berlin
# 1               0.00        3.85  2024-07-08 11:59:52        1  Berlin
# 2               0.00        2.49  2024-07-08 11:59:52        1  Berlin
# 3               0.00        2.28  2024-07-08 11:59:52        1  Berlin
# 4               0.00        2.07  2024-07-08 11:59:52        1  Berlin
# ..               ...         ...                  ...      ...     ...
# 115             0.32        2.54  2024-07-08 11:59:52        3  Munich
# 116             0.00        2.22  2024-07-08 11:59:52        3  Munich
# 117             0.36        2.10  2024-07-08 11:59:52        3  Munich
# 118             2.40        1.99  2024-07-08 11:59:52        3  Munich
# 119             0.45        2.11  2024-07-08 11:59:52        3  Munich
#
#      Country
# 0    Germany
# 1    Germany
# 2    Germany
# 3    Germany
# 4    Germany
# ..       ...
# 115  Germany
# 116  Germany
# 117  Germany
# 118  Germany
# 119  Germany
#
# [120 rows x 10 columns]

# %% [markdown]
# Renaming the columns with relevant names

# %%
weatherinfo_merged1.rename(columns={"forecast desc.": "forecast desc_"}, inplace=True)
weatherinfo_merged1
# Out:
#            forecast_time  temperature forecast   forecast desc_  \
# 0    2024-07-08 12:00:00        25.44    Clear        clear sky
# 1    2024-07-08 15:00:00        25.04   Clouds    broken clouds
# 2    2024-07-08 18:00:00        23.66   Clouds  overcast clouds
# 3    2024-07-08 21:00:00        20.44   Clouds  overcast clouds
# 4    2024-07-09 00:00:00        18.36   Clouds  overcast clouds
# ..                   ...          ...      ...              ...
# 115  2024-07-12 21:00:00        16.52     Rain       light rain
# 116  2024-07-13 00:00:00        16.85   Clouds  overcast clouds
# 117  2024-07-13 03:00:00        16.77     Rain       light rain
# 118  2024-07-13 06:00:00        16.68     Rain       light rain
# 119  2024-07-13 09:00:00        17.63     Rain       light rain
#
#      rain_in_last_3h  wind_speed    data_retrieved_at  City_id    City  \
# 0               0.00        3.55  2024-07-08 11:59:52        1  Berlin
# 1               0.00        3.85  2024-07-08 11:59:52        1  Berlin
# 2               0.00        2.49  2024-07-08 11:59:52        1  Berlin
# 3               0.00        2.28  2024-07-08 11:59:52        1  Berlin
# 4               0.00        2.07  2024-07-08 11:59:52        1  Berlin
# ..               ...         ...                  ...      ...     ...
# 115             0.32        2.54  2024-07-08 11:59:52        3  Munich
# 116             0.00        2.22  2024-07-08 11:59:52        3  Munich
# 117             0.36        2.10  2024-07-08 11:59:52        3  Munich
# 118             2.40        1.99  2024-07-08 11:59:52        3  Munich
# 119             0.45        2.11  2024-07-08 11:59:52        3  Munich
#
#      Country
# 0    Germany
# 1    Germany
# 2    Germany
# 3    Germany
# 4    Germany
# ..       ...
# 115  Germany
# 116  Germany
# 117  Germany
# 118  Germany
# 119  Germany
#
# [120 rows x 10 columns]

# %%
weatherinfo_merged1 = weatherinfo_merged1.drop(columns = "city")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\USER_N~1\AppData\Local\Temp/ipykernel_12296/4057563422.py in <module>
# ----> 1 weatherinfo_merged1 = weatherinfo_merged1.drop(columns = "city")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['city'] not found in axis"

# %%
weatherinfo_merged1
# Out:
#            forecast_time  temperature forecast   forecast desc_  \
# 0    2024-07-08 12:00:00        25.44    Clear        clear sky
# 1    2024-07-08 15:00:00        25.04   Clouds    broken clouds
# 2    2024-07-08 18:00:00        23.66   Clouds  overcast clouds
# 3    2024-07-08 21:00:00        20.44   Clouds  overcast clouds
# 4    2024-07-09 00:00:00        18.36   Clouds  overcast clouds
# ..                   ...          ...      ...              ...
# 115  2024-07-12 21:00:00        16.52     Rain       light rain
# 116  2024-07-13 00:00:00        16.85   Clouds  overcast clouds
# 117  2024-07-13 03:00:00        16.77     Rain       light rain
# 118  2024-07-13 06:00:00        16.68     Rain       light rain
# 119  2024-07-13 09:00:00        17.63     Rain       light rain
#
#      rain_in_last_3h  wind_speed    data_retrieved_at  City_id    City  \
# 0               0.00        3.55  2024-07-08 11:59:52        1  Berlin
# 1               0.00        3.85  2024-07-08 11:59:52        1  Berlin
# 2               0.00        2.49  2024-07-08 11:59:52        1  Berlin
# 3               0.00        2.28  2024-07-08 11:59:52        1  Berlin
# 4               0.00        2.07  2024-07-08 11:59:52        1  Berlin
# ..               ...         ...                  ...      ...     ...
# 115             0.32        2.54  2024-07-08 11:59:52        3  Munich
# 116             0.00        2.22  2024-07-08 11:59:52        3  Munich
# 117             0.36        2.10  2024-07-08 11:59:52        3  Munich
# 118             2.40        1.99  2024-07-08 11:59:52        3  Munich
# 119             0.45        2.11  2024-07-08 11:59:52        3  Munich
#
#      Country
# 0    Germany
# 1    Germany
# 2    Germany
# 3    Germany
# 4    Germany
# ..       ...
# 115  Germany
# 116  Germany
# 117  Germany
# 118  Germany
# 119  Germany
#
# [120 rows x 10 columns]

# %%
weatherinfo_merged1.rename(columns={"forecast desc_": "forecast_desc"}, inplace=True)
weatherinfo_merged1
# Out:
#            forecast_time  temperature forecast    forecast_desc  \
# 0    2024-07-08 12:00:00        25.44    Clear        clear sky
# 1    2024-07-08 15:00:00        25.04   Clouds    broken clouds
# 2    2024-07-08 18:00:00        23.66   Clouds  overcast clouds
# 3    2024-07-08 21:00:00        20.44   Clouds  overcast clouds
# 4    2024-07-09 00:00:00        18.36   Clouds  overcast clouds
# ..                   ...          ...      ...              ...
# 115  2024-07-12 21:00:00        16.52     Rain       light rain
# 116  2024-07-13 00:00:00        16.85   Clouds  overcast clouds
# 117  2024-07-13 03:00:00        16.77     Rain       light rain
# 118  2024-07-13 06:00:00        16.68     Rain       light rain
# 119  2024-07-13 09:00:00        17.63     Rain       light rain
#
#      rain_in_last_3h  wind_speed    data_retrieved_at  City_id    City  \
# 0               0.00        3.55  2024-07-08 11:59:52        1  Berlin
# 1               0.00        3.85  2024-07-08 11:59:52        1  Berlin
# 2               0.00        2.49  2024-07-08 11:59:52        1  Berlin
# 3               0.00        2.28  2024-07-08 11:59:52        1  Berlin
# 4               0.00        2.07  2024-07-08 11:59:52        1  Berlin
# ..               ...         ...                  ...      ...     ...
# 115             0.32        2.54  2024-07-08 11:59:52        3  Munich
# 116             0.00        2.22  2024-07-08 11:59:52        3  Munich
# 117             0.36        2.10  2024-07-08 11:59:52        3  Munich
# 118             2.40        1.99  2024-07-08 11:59:52        3  Munich
# 119             0.45        2.11  2024-07-08 11:59:52        3  Munich
#
#      Country
# 0    Germany
# 1    Germany
# 2    Germany
# 3    Germany
# 4    Germany
# ..       ...
# 115  Germany
# 116  Germany
# 117  Germany
# 118  Germany
# 119  Germany
#
# [120 rows x 10 columns]

# %% [markdown]
# Establishing SQL connection (not reall required if the connection has been already set up)

# %%
schema = #"your schema" # Name of Schema changes
host = #"host"
user = #"root"
password = #"your password" # Password changes
port = # port number

connection_string = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

# %% [markdown]
# ## Pushing the data to weather table in SQL

# %%
weatherinfo_merged1.to_sql('weather',
                  if_exists='append',
                  con=connection_string,
                  index=False)

# %% [markdown]
# ## Retrieveing the data from SQL (just to review)

# %%
weather_from_sql = pd.read_sql("weather", con = connection_string)
weather_from_sql
# Out:
#           forecast_time  temperature forecast    forecast_desc  \
# 0   2024-07-08 12:00:00        25.44    Clear        clear sky
# 1   2024-07-08 15:00:00        25.04   Clouds    broken clouds
# 2   2024-07-08 18:00:00        23.66   Clouds  overcast clouds
# 3   2024-07-08 21:00:00        20.44   Clouds  overcast clouds
# 4   2024-07-09 00:00:00        18.36   Clouds  overcast clouds
# ..                  ...          ...      ...              ...
# 115 2024-07-12 21:00:00        16.52     Rain       light rain
# 116 2024-07-13 00:00:00        16.85   Clouds  overcast clouds
# 117 2024-07-13 03:00:00        16.77     Rain       light rain
# 118 2024-07-13 06:00:00        16.68     Rain       light rain
# 119 2024-07-13 09:00:00        17.63     Rain       light rain
#
#      rain_in_last_3h  wind_speed   data_retrieved_at  City_id    City  Country
# 0               0.00        3.55 2024-07-08 11:59:52        1  Berlin  Germany
# 1               0.00        3.85 2024-07-08 11:59:52        1  Berlin  Germany
# 2               0.00        2.49 2024-07-08 11:59:52        1  Berlin  Germany
# 3               0.00        2.28 2024-07-08 11:59:52        1  Berlin  Germany
# 4               0.00        2.07 2024-07-08 11:59:52        1  Berlin  Germany
# ..               ...         ...                 ...      ...     ...      ...
# 115             0.32        2.54 2024-07-08 11:59:52        3  Munich  Germany
# 116             0.00        2.22 2024-07-08 11:59:52        3  Munich  Germany
# 117             0.36        2.10 2024-07-08 11:59:52        3  Munich  Germany
# 118             2.40        1.99 2024-07-08 11:59:52        3  Munich  Germany
# 119             0.45        2.11 2024-07-08 11:59:52        3  Munich  Germany
#
# [120 rows x 10 columns]

# %% [markdown]
# # Calling the airport (for multiple cities) function

# %% [markdown]
# Importing the essential libraries

# %%
import pandas as pd
from datetime import datetime, timedelta
import requests
from pytz import timezone

# %%
# Defining a function to retrieve ICAO airport codes given lists of latitudes and longitudes
def icao_airport_codes(latitudes, longitudes):
    
    # Assert len(latitudes) == len(longitudes)
    
    
    list_for_df = []  # Initializing an empty list to store dataframes
    
    for index, value in enumerate(latitudes): # Looping through the latitudes and corresponding longitudes
        url = f"https://aerodatabox.p.rapidapi.com/airports/search/location/{value}/{longitudes[index]}/km/50/5"
        querystring = {"withFlightInfoOnly":"true"}

        headers = {
          "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com",
          "X-RapidAPI-Key": #"X-RapidAPI-Key"
        }

        response = requests.request("GET", url, headers=headers, params=querystring)
        
        # Normalizing the JSON response and append the resulting dataframe to the list
        list_for_df.append(pd.json_normalize(response.json()['items']))
        

    return pd.concat(list_for_df, ignore_index=True)  # Concatenating all dataframes in the list into a single dataframe and return it

# %%
list(enumerate(latitudes)) # Create an enumerated list of tuples from the latitudes list (index, value)
# Out:
# [(0, 52.52), (1, 53.5511), (2, 48.1351)]

# %% [markdown]
# Calling the function

# %%
# Entering the coordinates for Berlin, Paris, London (Desired Cities)
latitudes = [52.5200, 53.5511, 48.1351]
longitudes = [13.4050, 9.9937, 11.5820]

icao_airport_codes(latitudes, longitudes) # Calling the function
# Out:
#    icao iata                name    shortName municipalityName countryCode  \
# 0  EDDB  BER  Berlin Brandenburg  Brandenburg           Berlin          DE
# 1  EDDH  HAM            Hamburg       Hamburg          Hamburg          DE
# 2  EDDM  MUC             Munich        Munich           Munich          DE
#
#         timeZone  location.lat  location.lon
# 0  Europe/Berlin      52.35139     13.493889
# 1  Europe/Berlin      53.63040      9.988229
# 2  Europe/Berlin      48.35380     11.786100

# %%
airport_df = icao_airport_codes(latitudes, longitudes)

# %%
airport_df
# Out:
#    icao iata                name    shortName municipalityName countryCode  \
# 0  EDDB  BER  Berlin Brandenburg  Brandenburg           Berlin          DE
# 1  EDDH  HAM            Hamburg       Hamburg          Hamburg          DE
# 2  EDDM  MUC             Munich        Munich           Munich          DE
#
#         timeZone  location.lat  location.lon
# 0  Europe/Berlin      52.35139     13.493889
# 1  Europe/Berlin      53.63040      9.988229
# 2  Europe/Berlin      48.35380     11.786100

# %%
# Creating a copy to keep original Dataframe untouched
airport_df1 = airport_df.copy()
airport_df1
# Out:
#    icao iata                name    shortName municipalityName countryCode  \
# 0  EDDB  BER  Berlin Brandenburg  Brandenburg           Berlin          DE
# 1  EDDH  HAM            Hamburg       Hamburg          Hamburg          DE
# 2  EDDM  MUC             Munich        Munich           Munich          DE
#
#         timeZone  location.lat  location.lon
# 0  Europe/Berlin      52.35139     13.493889
# 1  Europe/Berlin      53.63040      9.988229
# 2  Europe/Berlin      48.35380     11.786100

# %% [markdown]
# Merging airport with city table

# %%
airport_city_merged = airport_df1.merge(city_from_sql, left_on = "municipalityName", right_on = "City", how = "left")

airport_city_merged
# Out:
#    icao iata                name    shortName municipalityName countryCode  \
# 0  EDDB  BER  Berlin Brandenburg  Brandenburg           Berlin          DE
# 1  EDDH  HAM            Hamburg       Hamburg          Hamburg          DE
# 2  EDDM  MUC             Munich        Munich           Munich          DE
#
#         timeZone  location.lat  location.lon  City_id     City  Country
# 0  Europe/Berlin      52.35139     13.493889        1   Berlin  Germany
# 1  Europe/Berlin      53.63040      9.988229        2  Hamburg  Germany
# 2  Europe/Berlin      48.35380     11.786100        3   Munich  Germany

# %%
airport_city_merged
# Out:
#    icao iata                name    shortName municipalityName countryCode  \
# 0  EDDB  BER  Berlin Brandenburg  Brandenburg           Berlin          DE
# 1  EDDH  HAM            Hamburg       Hamburg          Hamburg          DE
# 2  EDDM  MUC             Munich        Munich           Munich          DE
#
#         timeZone  location.lat  location.lon  City_id     City  Country
# 0  Europe/Berlin      52.35139     13.493889        1   Berlin  Germany
# 1  Europe/Berlin      53.63040      9.988229        2  Hamburg  Germany
# 2  Europe/Berlin      48.35380     11.786100        3   Munich  Germany

# %%
airport_city_merged_copy = airport_city_merged.copy()

# %%
airport_city_merged_copy
# Out:
#    icao iata                name    shortName municipalityName countryCode  \
# 0  EDDB  BER  Berlin Brandenburg  Brandenburg           Berlin          DE
# 1  EDDH  HAM            Hamburg       Hamburg          Hamburg          DE
# 2  EDDM  MUC             Munich        Munich           Munich          DE
#
#         timeZone  location.lat  location.lon  City_id     City  Country
# 0  Europe/Berlin      52.35139     13.493889        1   Berlin  Germany
# 1  Europe/Berlin      53.63040      9.988229        2  Hamburg  Germany
# 2  Europe/Berlin      48.35380     11.786100        3   Munich  Germany

# %%
airports_df = airport_city_merged_copy = airport_city_merged_copy.drop(columns = ["iata", "shortName", "municipalityName" , "countryCode", "timeZone", "location.lat", "location.lon", "City_id", "City", "Country"])

# %%
airports_df
# Out:
#    icao                name
# 0  EDDB  Berlin Brandenburg
# 1  EDDH            Hamburg
# 2  EDDM             Munich

# %%
airports_df.rename(columns={"icao": "airport_icao", "name": "airport_name"}, inplace=True)
airports_df
# Out:
#   airport_icao        airport_name
# 0         EDDB  Berlin Brandenburg
# 1         EDDH            Hamburg
# 2         EDDM             Munich

# %% [markdown]
# ## Pushing the data to airports table in SQL

# %%
airports_df.to_sql('airports',
                  if_exists='append',
                  con=connection_string,
                  index=False)

# %%
airport_df_fromsql = pd.read_sql("airports", con = connection_string)
airport_df_fromsql
# Out:
#   airport_icao        airport_name
# 0         EDDB  Berlin Brandenburg
# 1         EDDH            Hamburg
# 2         EDDM             Munich

# %%
airport_city_merged_copy
# Out:
#   airport_icao        airport_name
# 0         EDDB  Berlin Brandenburg
# 1         EDDH            Hamburg
# 2         EDDM             Munich

# %%
airport_city_merged_copy2 = airport_city_merged.copy()
airport_city_merged_copy2
# Out:
#    icao iata                name    shortName municipalityName countryCode  \
# 0  EDDB  BER  Berlin Brandenburg  Brandenburg           Berlin          DE
# 1  EDDH  HAM            Hamburg       Hamburg          Hamburg          DE
# 2  EDDM  MUC             Munich        Munich           Munich          DE
#
#         timeZone  location.lat  location.lon  City_id     City  Country
# 0  Europe/Berlin      52.35139     13.493889        1   Berlin  Germany
# 1  Europe/Berlin      53.63040      9.988229        2  Hamburg  Germany
# 2  Europe/Berlin      48.35380     11.786100        3   Munich  Germany

# %%
cities_airports_df = airport_city_merged_copy2.drop(columns = ["iata", "name", "shortName", "municipalityName" , "countryCode", "timeZone", "location.lat", "location.lon", "City", "Country"])
cities_airports_df
# Out:
#    icao  City_id
# 0  EDDB        1
# 1  EDDH        2
# 2  EDDM        3

# %%
cities_airports_df.rename(columns={"icao": "airport_icao"}, inplace=True)
cities_airports_df
# Out:
#   airport_icao  City_id
# 0         EDDB        1
# 1         EDDH        2
# 2         EDDM        3

# %% [markdown]
# ## Pushing the data to cities_airport table in SQL

# %%
airport_city_merged1.rename(columns={"icao": "airport_icao"}, inplace=True)
airport_city_merged1
# Out:
#   airport_icao  City_id
# 0         EDDB        1
# 1         EDDH        2
# 2         EDDM        3

# %%
schema = #"your schema" # Name of Schema changes
host = #"host"
user = #"root"
password = #"your password" # Password changes
port = #port number

connection_string = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

# %%
airport_city_merged1.to_sql('cities_airport',
                  if_exists='append',
                  con=connection_string,
                  index=False)

# %%
airport_city_merged1_fromsql = pd.read_sql("cities_airport", con = connection_string)
airport_city_merged1_fromsql
# Out:
#   airport_icao  City_id
# 0         EDDB        1
# 1         EDDH        2
# 2         EDDM        3

# %% [markdown]
# # Calling the flight data for multiple cities function

# %% [markdown]
# Importing the essential libraries

# %%
import pandas as pd
from datetime import datetime, timedelta
import requests
from pytz import timezone

# %%
import pandas as pd
from datetime import datetime, timedelta
import requests
from pytz import timezone

def get_flight_data(icao_list):
  api_key = #"your API key"

  berlin_timezone = timezone('Europe/Berlin')
  today = datetime.now(berlin_timezone).date()
  tomorrow = (today + timedelta(days=1))

  flight_items = []

  for icao in icao_list:
    # the api can only make 12 hour calls, therefore, two 12 hour calls make a full day
    # using the nested lists below we can make a morning call and extract the data
    # then make an afternoon call and extract the data
    times = [["00:00","11:59"],
             ["12:00","23:59"]]

    for time in times:
      url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/{tomorrow}T{time[0]}/{tomorrow}T{time[1]}"

      querystring = {"withLeg":"true",
                    "direction":"Arrival",
                    "withCancelled":"false",
                    "withCodeshared":"true",
                    "withCargo":"false",
                    "withPrivate":"false"}

      headers = {
          'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
          'x-rapidapi-key': #api_key
          }

      response = requests.request("GET",
                                  url,
                                  headers = headers,
                                  params = querystring)

      flights_json = response.json()

      retrieval_time = datetime.now(berlin_timezone).strftime("%Y-%m-%d %H:%M:%S")

      for item in flights_json["arrivals"]:
        flight_item = {
            "arrival_airport_icao": icao,
            "departure_airport_icao": item["departure"]["airport"].get("icao", None),
            "scheduled_arrival_time": item["arrival"]["scheduledTime"].get("local", None),
            'arrival_terminal': item['arrival'].get('terminal', None),
            "flight_number": item.get("number", None),
            "data_retrieved_at": retrieval_time
        }

        flight_items.append(flight_item)

  flights_df = pd.DataFrame(flight_items)
  flights_df["scheduled_arrival_time"] = flights_df["scheduled_arrival_time"].str[:-6]
  flights_df["scheduled_arrival_time"] = pd.to_datetime(flights_df["scheduled_arrival_time"])
  flights_df["data_retrieved_at"] = pd.to_datetime(flights_df["data_retrieved_at"])

  return flights_df

# %% [markdown]
# Calling the function

# %%
icao_list = ["EDDB", "EDDH", "EDDM"]

get_flight_data(icao_list)
# Out:
#     arrival_airport_icao departure_airport_icao scheduled_arrival_time  \
# 0                   EDDB                   BIKF    2024-07-09 06:15:00
# 1                   EDDB                   LTCC    2024-07-09 06:45:00
# 2                   EDDB                   LTBJ    2024-07-09 06:30:00
# 3                   EDDB                   None    2024-07-09 07:20:00
# 4                   EDDB                   EVRA    2024-07-09 07:40:00
# ..                   ...                    ...                    ...
# 922                 EDDM                   LEPA    2024-07-09 23:25:00
# 923                 EDDM                   EGLL    2024-07-09 23:15:00
# 924                 EDDM                   LPPT    2024-07-09 23:30:00
# 925                 EDDM                   LPMA    2024-07-09 23:15:00
# 926                 EDDM                   HEGN    2024-07-09 23:25:00
#
#     arrival_terminal flight_number   data_retrieved_at
# 0                  1        FI 518 2024-07-08 12:54:45
# 1                  1       XQ 1700 2024-07-08 12:54:45
# 2                  1        XQ 966 2024-07-08 12:54:45
# 3                  1        5F 611 2024-07-08 12:54:45
# 4                  1       A3 3219 2024-07-08 12:54:45
# ..               ...           ...                 ...
# 922                1       DE 1131 2024-07-08 12:54:46
# 923                2       LH 2481 2024-07-08 12:54:46
# 924                2        TP 556 2024-07-08 12:54:46
# 925                1       X3 2847 2024-07-08 12:54:46
# 926                1       X3 6683 2024-07-08 12:54:46
#
# [927 rows x 6 columns]

# %%
flights_df = get_flight_data(icao_list)
flights_df
# Out:
#     arrival_airport_icao departure_airport_icao scheduled_arrival_time  \
# 0                   EDDB                   BIKF    2024-07-09 06:15:00
# 1                   EDDB                   LTCC    2024-07-09 06:45:00
# 2                   EDDB                   LTBJ    2024-07-09 06:30:00
# 3                   EDDB                   None    2024-07-09 07:20:00
# 4                   EDDB                   EVRA    2024-07-09 07:40:00
# ..                   ...                    ...                    ...
# 922                 EDDM                   LEPA    2024-07-09 23:25:00
# 923                 EDDM                   EGLL    2024-07-09 23:15:00
# 924                 EDDM                   LPPT    2024-07-09 23:30:00
# 925                 EDDM                   LPMA    2024-07-09 23:15:00
# 926                 EDDM                   HEGN    2024-07-09 23:25:00
#
#     arrival_terminal flight_number   data_retrieved_at
# 0                  1        FI 518 2024-07-08 12:55:18
# 1                  1       XQ 1700 2024-07-08 12:55:18
# 2                  1        XQ 966 2024-07-08 12:55:18
# 3                  1        5F 611 2024-07-08 12:55:18
# 4                  1       A3 3219 2024-07-08 12:55:18
# ..               ...           ...                 ...
# 922                1       DE 1131 2024-07-08 12:55:20
# 923                2       LH 2481 2024-07-08 12:55:20
# 924                2        TP 556 2024-07-08 12:55:20
# 925                1       X3 2847 2024-07-08 12:55:20
# 926                1       X3 6683 2024-07-08 12:55:20
#
# [927 rows x 6 columns]

# %%
flights_df1 = flights_df.copy()
flights_df1
# Out:
#     arrival_airport_icao departure_airport_icao scheduled_arrival_time  \
# 0                   EDDB                   BIKF    2024-07-09 06:15:00
# 1                   EDDB                   LTCC    2024-07-09 06:45:00
# 2                   EDDB                   LTBJ    2024-07-09 06:30:00
# 3                   EDDB                   None    2024-07-09 07:20:00
# 4                   EDDB                   EVRA    2024-07-09 07:40:00
# ..                   ...                    ...                    ...
# 922                 EDDM                   LEPA    2024-07-09 23:25:00
# 923                 EDDM                   EGLL    2024-07-09 23:15:00
# 924                 EDDM                   LPPT    2024-07-09 23:30:00
# 925                 EDDM                   LPMA    2024-07-09 23:15:00
# 926                 EDDM                   HEGN    2024-07-09 23:25:00
#
#     arrival_terminal flight_number   data_retrieved_at
# 0                  1        FI 518 2024-07-08 12:55:18
# 1                  1       XQ 1700 2024-07-08 12:55:18
# 2                  1        XQ 966 2024-07-08 12:55:18
# 3                  1        5F 611 2024-07-08 12:55:18
# 4                  1       A3 3219 2024-07-08 12:55:18
# ..               ...           ...                 ...
# 922                1       DE 1131 2024-07-08 12:55:20
# 923                2       LH 2481 2024-07-08 12:55:20
# 924                2        TP 556 2024-07-08 12:55:20
# 925                1       X3 2847 2024-07-08 12:55:20
# 926                1       X3 6683 2024-07-08 12:55:20
#
# [927 rows x 6 columns]

# %%
flights_df1 = flights_df1.drop(columns = ["arrival_terminal", "data_retrieved_at",])

# %%
flights_df1
# Out:
#     arrival_airport_icao departure_airport_icao scheduled_arrival_time  \
# 0                   EDDB                   BIKF    2024-07-09 06:15:00
# 1                   EDDB                   LTCC    2024-07-09 06:45:00
# 2                   EDDB                   LTBJ    2024-07-09 06:30:00
# 3                   EDDB                   None    2024-07-09 07:20:00
# 4                   EDDB                   EVRA    2024-07-09 07:40:00
# ..                   ...                    ...                    ...
# 922                 EDDM                   LEPA    2024-07-09 23:25:00
# 923                 EDDM                   EGLL    2024-07-09 23:15:00
# 924                 EDDM                   LPPT    2024-07-09 23:30:00
# 925                 EDDM                   LPMA    2024-07-09 23:15:00
# 926                 EDDM                   HEGN    2024-07-09 23:25:00
#
#     flight_number
# 0          FI 518
# 1         XQ 1700
# 2          XQ 966
# 3          5F 611
# 4         A3 3219
# ..            ...
# 922       DE 1131
# 923       LH 2481
# 924        TP 556
# 925       X3 2847
# 926       X3 6683
#
# [927 rows x 4 columns]

# %%
flights_df1.rename(columns={"arrival_airport_icao": "arrival_icao", "departure_airport_icao": "departure_icao"}, inplace=True)
flights_df1
# Out:
#     arrival_icao departure_icao scheduled_arrival_time flight_number
# 0           EDDB           BIKF    2024-07-09 06:15:00        FI 518
# 1           EDDB           LTCC    2024-07-09 06:45:00       XQ 1700
# 2           EDDB           LTBJ    2024-07-09 06:30:00        XQ 966
# 3           EDDB           None    2024-07-09 07:20:00        5F 611
# 4           EDDB           EVRA    2024-07-09 07:40:00       A3 3219
# ..           ...            ...                    ...           ...
# 922         EDDM           LEPA    2024-07-09 23:25:00       DE 1131
# 923         EDDM           EGLL    2024-07-09 23:15:00       LH 2481
# 924         EDDM           LPPT    2024-07-09 23:30:00        TP 556
# 925         EDDM           LPMA    2024-07-09 23:15:00       X3 2847
# 926         EDDM           HEGN    2024-07-09 23:25:00       X3 6683
#
# [927 rows x 4 columns]

# %%
flights_df1['scheduled_arrival_time'] = pd.to_datetime(flights_df1['scheduled_arrival_time'])
flights_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 927 entries, 0 to 926
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   arrival_icao            927 non-null    object
#  1   departure_icao          924 non-null    object
#  2   scheduled_arrival_time  927 non-null    datetime64[ns]
#  3   flight_number           927 non-null    object
#  4   arrival_time            927 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), object(3)
# memory usage: 36.3+ KB

# %%
flights_df1
# Out:
#     arrival_icao departure_icao scheduled_arrival_time flight_number  \
# 0           EDDB           BIKF    2024-07-09 06:15:00        FI 518
# 1           EDDB           LTCC    2024-07-09 06:45:00       XQ 1700
# 2           EDDB           LTBJ    2024-07-09 06:30:00        XQ 966
# 3           EDDB           None    2024-07-09 07:20:00        5F 611
# 4           EDDB           EVRA    2024-07-09 07:40:00       A3 3219
# ..           ...            ...                    ...           ...
# 922         EDDM           LEPA    2024-07-09 23:25:00       DE 1131
# 923         EDDM           EGLL    2024-07-09 23:15:00       LH 2481
# 924         EDDM           LPPT    2024-07-09 23:30:00        TP 556
# 925         EDDM           LPMA    2024-07-09 23:15:00       X3 2847
# 926         EDDM           HEGN    2024-07-09 23:25:00       X3 6683
#
#            arrival_time
# 0   2024-07-09 06:15:00
# 1   2024-07-09 06:45:00
# 2   2024-07-09 06:30:00
# 3   2024-07-09 07:20:00
# 4   2024-07-09 07:40:00
# ..                  ...
# 922 2024-07-09 23:25:00
# 923 2024-07-09 23:15:00
# 924 2024-07-09 23:30:00
# 925 2024-07-09 23:15:00
# 926 2024-07-09 23:25:00
#
# [927 rows x 5 columns]

# %%
flights_df1 = flights_df1.drop(columns = "arrival_time")

# %%
flights_df1
# Out:
#     arrival_icao departure_icao scheduled_arrival_time flight_number
# 0           EDDB           BIKF    2024-07-09 06:15:00        FI 518
# 1           EDDB           LTCC    2024-07-09 06:45:00       XQ 1700
# 2           EDDB           LTBJ    2024-07-09 06:30:00        XQ 966
# 3           EDDB           None    2024-07-09 07:20:00        5F 611
# 4           EDDB           EVRA    2024-07-09 07:40:00       A3 3219
# ..           ...            ...                    ...           ...
# 922         EDDM           LEPA    2024-07-09 23:25:00       DE 1131
# 923         EDDM           EGLL    2024-07-09 23:15:00       LH 2481
# 924         EDDM           LPPT    2024-07-09 23:30:00        TP 556
# 925         EDDM           LPMA    2024-07-09 23:15:00       X3 2847
# 926         EDDM           HEGN    2024-07-09 23:25:00       X3 6683
#
# [927 rows x 4 columns]

# %%
schema = #"your schema" # Name of Schema changes
host = #"host"
user = #"root"
password = #"password" # Password changes
port = # port number

connection_string = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

# %% [markdown]
# ## Pushing the data to flights table in SQL

# %%
flights_df1.to_sql('flights',
                  if_exists='append',
                  con=connection_string,
                  index=False)
